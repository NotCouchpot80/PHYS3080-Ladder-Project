# %% [markdown]
# ## Project setup

# %%
# import required libraries
import os
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.table import Table
import glob
import warnings
from sklearn import mixture
from sklearn.neighbors import KernelDensity
import itertools
import seaborn as sns
from sklearn.utils.fixes import parse_version

# 
# configure notebook for plotting
# %pylab inline --no-import-all 
mpl.style.use('seaborn-colorblind') # colourblind-friendly colour scheme
colours = mpl.rcParams['axes.prop_cycle'].by_key()['color'] # allows access to colours
# subsequent lines default plot settings
matplotlib.rcParams['image.origin'] = 'lower'
matplotlib.rcParams['figure.figsize']=(20,5)  
matplotlib.rcParams['font.size']=16    
matplotlib.rcParams['savefig.dpi']= 300   
warnings.filterwarnings('ignore')

# functions
def in_hull(p, hull):
    # """
    # code from https://stackoverflow.com/questions/16750618/whats-an-efficient-way-to-find-if-a-point-lies-in-the-convex-hull-of-a-point-cl, by user Juh_
    # Test if points in `p` are in `hull`

    # `p` should be a `NxK` coordinates of `N` points in `K` dimensions
    # `hull` is either a scipy.spatial.Delaunay object or the `MxK` array of the 
    # coordinates of `M` points in `K`dimensions for which Delaunay triangulation
    # will be computed
    # """
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)

    return hull.find_simplex(p)>=0
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Initial data entry

# %%
# import data from Data directory
allPointsFiles = glob.glob('../Data/*/*/points.txt')
allFuzzyFiles = glob.glob('../Data/*/*/fuzzy.txt')
allVaryingPointFiles = glob.glob('../Data/*/*/P*.csv')
allXrayFiles = glob.glob('../Data/XrayFlash.txt')

# initiate initial variables
farPoints = []
midPoints = []
closePoints = []
allPoints = []
variablePoints = []
xRayPoints = []
fuzzies = []
name2ID = []
# initial loading and sorting
# points (row = [name, x, y, distance, HRx, HRy, RV])

# initiate parameters
upperParallaxLimit = 0.006
lowerParallaxLimit = 0.005
ID=100000
# sort the points
for j, pointsFile in enumerate(allPointsFiles):
    try:
        this = Table.read(pointsFile,format='ascii')
        thispar = this['par']
        thism0, thism1, thism2 = (np.log10(this['flux1']), 
                                  np.log10(this['flux2']), 
                                  np.log10(this['flux3']))
        thiscolour = thism2-thism0
        # transform coords onto "sky net" based on file path and store in numpy array          
        if pointsFile.rfind('Up')!=-1:
            points = np.array([this['name'], this['y'], -this['x']+90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Front')!=-1:
            points = np.array([this['name'], this['y']-90, -this['x']+90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Right')!=-1:
            points = np.array([this['name'], this['x'], this['y'], thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Back')!=-1:
            points = np.array([this['name'], this['x']+90, this['y'], thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Left')!=-1:
            points = np.array([this['name'], this['y']-90, -this['x']+180, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Down')!=-1:
            points = np.array([this['name'], this['y'], -this['x']-90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
            
        # sort into close and far
        for point in points:
            ID=ID+1
            name2ID.append([point[0],ID])
            point[0]=str(ID)
            if float(point[3]) > upperParallaxLimit:
                closePoints.append(point)
            elif float(point[3]) <= lowerParallaxLimit:# value chosen to minimize clusters being assigned to mid distance
                farPoints.append(point)   
            else:
                midPoints.append(point)  
    except Exception as e:
        print('Failed point sorting: '+ str(e))
        pass
closePoints=np.array(closePoints).astype(np.float)
midPoints=np.array(midPoints).astype(np.float).astype(np.float)
farPoints=np.array(farPoints).astype(np.float)
allPoints=np.concatenate((closePoints, midPoints, farPoints),axis=0).astype(np.float)
name2ID=np.array(name2ID)
# fuzzies (row = [name, x, y, flux1, flux2, flux3, width, RV])
for j, fuzzyFile in enumerate(allFuzzyFiles):
    fuzzy=[]
    try:
        this = Table.read(fuzzyFile,format='ascii')
        # transform coords onto "sky net" based on file path and store in numpy array          
        if pointsFile.rfind('Up')!=-1:
            fuzzy = np.array([this['name'], this['y'], -this['x']+90,this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Front')!=-1:
            fuzzy = np.array([this['name'], this['y']-90, -this['x']+90, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Right')!=-1:
            fuzzy = np.array([this['name'], this['x'], this['y'], this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Back')!=-1:
            fuzzy = np.array([this['name'], this['x']+90, this['y'], this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Left')!=-1:
            fuzzy = np.array([this['name'], this['y']-90, -this['x']+180, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Down')!=-1:
            fuzzy = np.array([this['name'], this['y'], -this['x']-90, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
    except:
        pass
    fuzzies.append(fuzzy)
fuzzies = np.array(fuzzies).astype(np.float)

# Xray flashes (row = [x, y, luminosity])
for j, XrayFiles in enumerate(allXrayFiles):
    Xrays = []
    try:
        this = Table.read(XrayFiles,format='ascii')
        for line in this:
            # transform coords onto "sky net" based on file path and store in numpy array          
            if line['Camera']==('Up'):
                Xrays = np.array([line['y'], -line['x']+90, line['mag']]).T.tolist()
            elif line['Camera']==('Front'):
                Xrays = np.array([ line['y']-90, -line['x']+90, line['mag']]).T.tolist()
            elif line['Camera']==('Right'):
                Xrays = np.array([ line['x'], line['y'], line['mag']]).T.tolist()
            elif line['Camera']==('Back'):
                Xrays = np.array([line['x']+90, line['y'], line['mag']]).T.tolist()
            elif line['Camera']==('Left'):
                Xrays = np.array([ line['y']-90, -line['x']+180, line['mag']]).T.tolist()
            elif line['Camera']==('Down'):
                Xrays = np.array([ line['y'], -line['x']-90, line['mag']]).T.tolist()

            xRayPoints.append(Xrays)
    except Exception as e:
        logger.error('Failed: '+ str(e))
        pass
xRayflashes=np.array(xRayPoints).astype(np.float)

# Variable points (row = [name, x, y, dist, HRx, HRy, abs mag, RV, variable data])
for j, varsFile in enumerate(allVaryingPointFiles):
    
    try:
        thisVar = np.array(Table.read(varsFile,format='ascii'))
        name = varsFile[-10:-4]
        pointID=name2ID[name2ID[:,0]==name,1][0]
        basicData=allPoints[(allPoints[:,0]==pointID.astype(np.float)),:]
        variablePoint=np.array([basicData[0,0],basicData[0,1],basicData[0,2],basicData[0,3],basicData[0,4],basicData[0,5],basicData[0,6],thisVar])
        variablePoints.append(variablePoint)
    except Exception as e:
        print('Failed: '+ str(e))
        print(varsFile[-10:-4])
        pass
variablePoints=np.array(variablePoints)

# %% [markdown]
# ## Calculate HRy flattener

# %%
# transform HRy
absMag = closePoints[:,5].astype(np.float) + 2*np.log10(1/closePoints[:,3].astype(np.float))
BenchMark = np.array([closePoints[:,4].astype(np.float), absMag]).T
branches=[]
# Identify benchmark main seqence cluster with BGMM
branchCount = 4   # clusterCount
tol=0.0005
countStep = 5
CountTrials = 10
branchesModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                n_components=branchCount,
                covariance_type="full",
                n_init = CountTrials
                )).fit(BenchMark)    
branchShapes = branchesModel.predict(BenchMark)
# Collate branch points
for i, (weights) in enumerate(branchesModel.weights_):
    if not np.any(branchShapes == i) or weights<(0.01/branchCount):
        continue        
    branches.append(BenchMark[branchShapes == i, :])
## get Main sequence to fit polynomial
clusterSize=0
i=0
MSindex=0
for branch in branches:
    if len(branch)>clusterSize:
        clusterSize=len(branch)
        MSindex=i
    i=i+1
mainSequenceBenchmark=branches[MSindex]
MSFit4=np.poly1d(np.polyfit(mainSequenceBenchmark[:,0],mainSequenceBenchmark[:,1],4))
MSFit1=np.poly1d(np.polyfit(mainSequenceBenchmark[:,0],mainSequenceBenchmark[:,1],1))
# Transform all close points HR values
BenchMarktHRx=BenchMark[:,0]
BenchMarktHRy=BenchMark[:,1]-np.power(BenchMark[:,0],4)*MSFit4.c[0]-np.power(BenchMark[:,0],3)*MSFit4.c[1]-np.power(BenchMark[:,0],2)*MSFit4.c[2]-BenchMark[:,0]*MSFit4.c[3]-MSFit4.c[4]
linearBenchMarktHRy=BenchMark[:,1]-BenchMark[:,0]*MSFit1.c[0]-MSFit1.c[1]

# %% [markdown]
# ## breakdown point clusters

# %%
# Initiate output arrays
protoClusters = []
subClusters = []    #row = [ID, x, y, HRx, tHRy, rv]
clusters = []
# initiate input arrays
# X row = [ID, x, y, HRx, HRy, rv]
unassigned = []
# get protoClusters
X=np.concatenate([farPoints[:,[0,1,2,4,5,6]], midPoints[:,[0,1,2,4,5,6]]]).astype(np.float)
numberOfClusters = 1
NOCinc = 1
trials = 1
tol=0.001
WCP = 1
MPR = 1
minClusterSize=4
features=[1,2,5]
ProtoClustersModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                weight_concentration_prior=WCP,
                mean_precision_prior=MPR,
                n_components=numberOfClusters,
                covariance_type="full",
                n_init = trials
                )).fit(X[:,features])
while min(ProtoClustersModel.weights_)>(0.01/numberOfClusters):
    
    numberOfClusters=numberOfClusters+NOCinc
    
    ProtoClustersModel = (mixture.BayesianGaussianMixture(
                    weight_concentration_prior=WCP,
                    mean_precision_prior=MPR,
                    tol=tol,
                    n_components=numberOfClusters,
                    covariance_type="full",
                    n_init = trials
                    )).fit(X[:,features])
ProtoClustersModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                weight_concentration_prior=WCP,
                mean_precision_prior=MPR,
                n_components=numberOfClusters-1,
                covariance_type="full",
                n_init = trials
                )).fit(X[:,features])
protoClusterShapes = ProtoClustersModel.predict(X[:,features])
for i, weights in enumerate(ProtoClustersModel.weights_):
    
    if not np.any(protoClusterShapes == i) or weights<(0.01/numberOfClusters) or len(X[protoClusterShapes == i, :])<minClusterSize:
        print('rejected: ', str(len(X[protoClusterShapes == i, :])))
        try:
            unassigned.append(X[protoClusterShapes == i, :].tolist()[0])
            continue
        except:
            continue
    protoClusters.append(X[protoClusterShapes == i, :])

    
    
# get subClusters
for protoCluster in protoClusters:
    # parameters
    tol=0.001
    numberOfSubClusterCount = 3   #initial clusterCount
    minSubclusterSize = 30
    features=[1,2,5]
    subClustersModel = (mixture.BayesianGaussianMixture(
                        tol=tol,
                        n_components=numberOfSubClusterCount,
                        covariance_type="full",
                        )).fit(protoCluster[:,features])
    while min(subClustersModel.weights_)>(0.1/numberOfSubClusterCount):
        numberOfSubClusterCount = numberOfSubClusterCount + 1
        subClustersModel = (mixture.BayesianGaussianMixture(
                            tol=tol,
                            n_components=numberOfSubClusterCount,
                            covariance_type="full",
                            )).fit(protoCluster[:,features])
    subClustersModel = (mixture.BayesianGaussianMixture(
                        tol=tol,
                        n_components=numberOfSubClusterCount-1,
                        covariance_type="full",
                        )).fit(protoCluster[:,features])
    subClusterShapes = subClustersModel.predict(protoCluster[:,features])
# collate subclusters
    for i, (weights) in enumerate(subClustersModel.weights_):
        if not np.any(subClusterShapes == i) or len(protoCluster[subClusterShapes == i, :])<minSubclusterSize:
            try:
                unassigned.append(protoCluster[subClusterShapes == i, :].tolist()[0])
                continue
            except:
                continue
        temp=protoCluster[subClusterShapes == i, :]
        subClusters.append(np.array([temp[:,0],temp[:,1],temp[:,2],temp[:,3],temp[:,4], temp[:,5]]).T)
subClusters=np.array(subClusters)

# %% [markdown]
# ## Rebuild points clusters

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d, Delaunay
from scipy.interpolate import griddata
# Calculate prereq cluster data (boundary, Main sequence HRy, RV profile)
# 
        # tHRy = temp[:,4]-np.square(temp[:,3])*MSFit.c[0]-temp[:,3]*MSFit.c[1]-MSFit.c[2]

subClusterMS = []
boundaries = []
RVP = []
for subCluster in subClusters:
    Xms = np.array([subCluster[:,3], subCluster[:,4]-np.power(subCluster[:,3],4)*MSFit4.c[0]-np.power(subCluster[:,3],3)*MSFit4.c[1]-np.power(subCluster[:,3],2)*MSFit4.c[2]-subCluster[:,3]*MSFit4.c[3]-MSFit4.c[4]]).T
    ltHRy = np.array([subCluster[:,3],subCluster[:,4]-subCluster[:,3]*MSFit1.c[0]-MSFit1.c[1]]).T

    branches=[]
    # Identify benchmark main seqence cluster with BGMM
    branchCount = 3   # clusterCount
    countStep = 5
    CountTrials = 3
    branchesModel = (mixture.BayesianGaussianMixture(
                    n_components=branchCount,
                    covariance_type="full",
                    n_init = CountTrials
                    )).fit(ltHRy)    
    branchShapes = branchesModel.predict(ltHRy)
    # Collate branch points
    for i, (weights) in enumerate(branchesModel.weights_):
        if not np.any(branchShapes == i) or weights<(0.01/branchCount):
            continue        
        branches.append(Xms[branchShapes == i, :])
    ## get Main sequence to fit polynomial
    clusterSize=0
    i=0
    MSindex=0
    for branch in branches:
        if len(branch)>clusterSize:
            clusterSize=len(branch)
            MSindex=i
        i=i+1
    subClusterMS.append(branches[MSindex][branches[MSindex][:,0]>-0.6,:])
    
    
    boundary=subCluster[:,[1,2]]
    boundaries.append(Delaunay(boundary))   
    # get RVfit
    xi, yi = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))
    RVP.append(griddata(subCluster[:,[1,2]], subCluster[:,5], (xi,yi), method='cubic'))
    
boundaries = np.array(boundaries) 
xi, yi = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))   
clusters = subClusters
clusterMS = np.array(subClusterMS)
exists = np.ones(len(clusters)).astype(int)
oldExistSum=np.infty
while np.sum(exists)<oldExistSum:
    oldExistSum=np.sum(exists)
    exists = np.ones(len(clusters)).astype(int)
    for h, hostCluster in enumerate(clusters):
        # get cluster boundary
        if exists[h]==1:
            for i, otherCluster in enumerate(clusters):
                overlap = sum(abs(in_hull(otherCluster[:,[1,2]], boundaries[h])))
                difMeans = np.sqrt((np.mean(otherCluster[:,1])-np.mean(hostCluster[:,1]))**2 + (np.mean(otherCluster[:,2])-np.mean(hostCluster[:,2]))**2)
                maxRH = max(np.sqrt((hostCluster[:,1]-np.mean(hostCluster[:,1]))**2 + (hostCluster[:,2]-np.mean(hostCluster[:,2]))**2))
                maxRO = max(np.sqrt((otherCluster[:,1]-np.mean(otherCluster[:,1]))**2 + (otherCluster[:,2]-np.mean(otherCluster[:,2]))**2))
                maxR =maxRH + maxRO
                print("Host: ", h, ', index: ', i, 'overlap: ', overlap)
                if (exists[i]==1                                          # only use existing clusters
                and i != h
                and (overlap>0                                        # overlap checker
                or difMeans<maxR)
                   ):
                        tTest=sp.stats.ttest_ind(clusterMS[h][:,1], clusterMS[i][:,1], axis=0, equal_var=False)
                        print('        ',tTest)
                        if tTest[1]>0.05:
                            print('        ', h, ' match with ', i)
                            
                            clusters[h] = np.append(clusters[h],clusters[i],axis=0)      # Update host
                            clusters[h] = np.append(clusters[h],clusters[i],axis=0)                     # Update host
                            boundaries[h] = Delaunay(clusters[h][:,[1,2]])
                            clusterMS[h] =  np.append(clusterMS[h],clusterMS[i],axis=0) 
                            # RVP[h] = sp.griddata(clusters[:,[1,2]], clusters[:,5], (xi,yi), method='cubic')
                            exists[i] = 0
    clusters=clusters[exists == 1]
    boundaries = boundaries[exists == 1]    
    clusterMS = clusterMS[exists == 1]
# Out:
# Host:  0 , index:  0 overlap:  2471
# Host:  0 , index:  1 overlap:  36
#          Ttest_indResult(statistic=1.906057759634537, pvalue=0.07392541176815373)
#          0  match with  1
# Host:  0 , index:  2 overlap:  122
#          Ttest_indResult(statistic=35.85722671939671, pvalue=3.19455830805952e-51)
# Host:  0 , index:  3 overlap:  106
#          Ttest_indResult(statistic=-0.36775872448239555, pvalue=0.7139607037572361)
#          0  match with  3
# Host:  0 , index:  4 overlap:  0
# Host:  0 , index:  5 overlap:  0
# Host:  0 , index:  6 overlap:  0
# Host:  0 , index:  7 overlap:  0
# Host:  0 , index:  8 overlap:  0
# Host:  0 , index:  9 overlap:  0
# Host:  0 , index:  10 overlap:  0
# Host:  0 , index:  11 overlap:  0
#          Ttest_indResult(statistic=-20.568967551668926, pvalue=2.8230574031231348e-90)
# Host:  0 , index:  12 overlap:  0
# Host:  0 , index:  13 overlap:  0
# Host:  0 , index:  14 overlap:  0
#          Ttest_indResult(statistic=-6.722664728142562, pvalue=3.807240853372132e-10)
# Host:  0 , index:  15 overlap:  0
# Host:  0 , index:  16 overlap:  0
# Host:  0 , index:  17 overlap:  0
# Host:  0 , index:  18 overlap:  0
# Host:  0 , index:  19 overlap:  0
# Host:  0 , index:  20 overlap:  0
# Host:  0 , index:  21 overlap:  0
# Host:  0 , index:  22 overlap:  0
# Host:  0 , index:  23 overlap:  0
# Host:  0 , index:  24 overlap:  0
# Host:  0 , index:  25 overlap:  0
# Host:  0 , index:  26 overlap:  0
# Host:  0 , index:  27 overlap:  0
# Host:  0 , index:  28 overlap:  0
# Host:  0 , index:  29 overlap:  0
# Host:  0 , index:  30 overlap:  0
# Host:  0 , index:  31 overlap:  0
# Host:  0 , index:  32 overlap:  0
# Host:  0 , index:  33 overlap:  0
# Host:  0 , index:  34 overlap:  0
# Host:  2 , index:  0 overlap:  36
#          Ttest_indResult(statistic=-35.89001826784831, pvalue=3.5293090255419566e-51)
# Host:  2 , index:  1 overlap:  2
# Host:  2 , index:  2 overlap:  124
# Host:  2 , index:  3 overlap:  0
# Host:  2 , index:  4 overlap:  0
# Host:  2 , index:  5 overlap:  0
# Host:  2 , index:  6 overlap:  0
# Host:  2 , index:  7 overlap:  0
# Host:  2 , index:  8 overlap:  0
# Host:  2 , index:  9 overlap:  0
# Host:  2 , index:  10 overlap:  0
# Host:  2 , index:  11 overlap:  0
#          Ttest_indResult(statistic=-40.586917582832456, pvalue=4.494027892786299e-55)
# Host:  2 , index:  12 overlap:  0
# Host:  2 , index:  13 overlap:  0
# Host:  2 , index:  14 overlap:  0
# Host:  2 , index:  15 overlap:  0
# Host:  2 , index:  16 overlap:  0
# Host:  2 , index:  17 overlap:  0
# Host:  2 , index:  18 overlap:  0
# Host:  2 , index:  19 overlap:  0
# Host:  2 , index:  20 overlap:  0
# Host:  2 , index:  21 overlap:  0
# Host:  2 , index:  22 overlap:  0
# Host:  2 , index:  23 overlap:  0
# Host:  2 , index:  24 overlap:  0
# Host:  2 , index:  25 overlap:  0
# Host:  2 , index:  26 overlap:  0
# Host:  2 , index:  27 overlap:  0
# Host:  2 , index:  28 overlap:  0
# Host:  2 , index:  29 overlap:  0
# Host:  2 , index:  30 overlap:  0
# Host:  2 , index:  31 overlap:  0
# Host:  2 , index:  32 overlap:  0
# Host:  2 , index:  33 overlap:  0
# Host:  2 , index:  34 overlap:  0
# Host:  4 , index:  0 overlap:  0
# Host:  4 , index:  1 overlap:  0
# Host:  4 , index:  2 overlap:  0
# Host:  4 , index:  3 overlap:  0
# Host:  4 , index:  4 overlap:  8864
# Host:  4 , index:  5 overlap:  107
#          Ttest_indResult(statistic=-0.10055143194375765, pvalue=0.9201588909294489)
#          4  match with  5
# Host:  4 , index:  6 overlap:  42
#          Ttest_indResult(statistic=-1.488099554889476, pvalue=0.1478235542102561)
#          4  match with  6
# Host:  4 , index:  7 overlap:  601
#          Ttest_indResult(statistic=1.0777726516352768, pvalue=0.28165007966868905)
#          4  match with  7
# Host:  4 , index:  8 overlap:  0
# Host:  4 , index:  9 overlap:  0
# Host:  4 , index:  10 overlap:  0
# Host:  4 , index:  11 overlap:  0
# Host:  4 , index:  12 overlap:  0
# Host:  4 , index:  13 overlap:  0
# Host:  4 , index:  14 overlap:  0
# Host:  4 , index:  15 overlap:  0
# Host:  4 , index:  16 overlap:  0
# Host:  4 , index:  17 overlap:  0
# Host:  4 , index:  18 overlap:  0
# Host:  4 , index:  19 overlap:  0
# Host:  4 , index:  20 overlap:  0
# Host:  4 , index:  21 overlap:  0
# Host:  4 , index:  22 overlap:  0
# Host:  4 , index:  23 overlap:  0
# Host:  4 , index:  24 overlap:  0
# Host:  4 , index:  25 overlap:  0
# Host:  4 , index:  26 overlap:  0
# Host:  4 , index:  27 overlap:  0
# Host:  4 , index:  28 overlap:  0
# Host:  4 , index:  29 overlap:  0
# Host:  4 , index:  30 overlap:  0
# Host:  4 , index:  31 overlap:  0
# Host:  4 , index:  32 overlap:  0
# Host:  4 , index:  33 overlap:  0
# Host:  4 , index:  34 overlap:  0
# Host:  8 , index:  0 overlap:  0
# Host:  8 , index:  1 overlap:  0
# Host:  8 , index:  2 overlap:  0
# Host:  8 , index:  3 overlap:  0
# Host:  8 , index:  4 overlap:  0
# Host:  8 , index:  5 overlap:  0
# Host:  8 , index:  6 overlap:  0
# Host:  8 , index:  7 overlap:  0
# Host:  8 , index:  8 overlap:  4943
# Host:  8 , index:  9 overlap:  367
#          Ttest_indResult(statistic=-1.5516763907557394, pvalue=0.1217484816427609)
#          8  match with  9
# Host:  8 , index:  10 overlap:  31
#          Ttest_indResult(statistic=0.4975663449521854, pvalue=0.6236163205708491)
#          8  match with  10
# Host:  8 , index:  11 overlap:  0
# Host:  8 , index:  12 overlap:  0
# Host:  8 , index:  13 overlap:  0
# Host:  8 , index:  14 overlap:  0
# Host:  8 , index:  15 overlap:  0
# Host:  8 , index:  16 overlap:  0
# Host:  8 , index:  17 overlap:  0
# Host:  8 , index:  18 overlap:  0
# Host:  8 , index:  19 overlap:  0
# Host:  8 , index:  20 overlap:  0
# Host:  8 , index:  21 overlap:  0
# Host:  8 , index:  22 overlap:  0
# Host:  8 , index:  23 overlap:  0
# Host:  8 , index:  24 overlap:  0
# Host:  8 , index:  25 overlap:  0
# Host:  8 , index:  26 overlap:  0
# Host:  8 , index:  27 overlap:  0
#          Ttest_indResult(statistic=162.12749644984572, pvalue=0.0)
# Host:  8 , index:  28 overlap:  0
#          Ttest_indResult(statistic=84.14485379420648, pvalue=1.415578101315709e-182)
# Host:  8 , index:  29 overlap:  0
# Host:  8 , index:  30 overlap:  0
# Host:  8 , index:  31 overlap:  0
# Host:  8 , index:  32 overlap:  0
# Host:  8 , index:  33 overlap:  0
# Host:  8 , index:  34 overlap:  0
# Host:  11 , index:  0 overlap:  0
#          Ttest_indResult(statistic=20.568967551668926, pvalue=2.8230574031231348e-90)
# Host:  11 , index:  1 overlap:  0
# Host:  11 , index:  2 overlap:  0
#          Ttest_indResult(statistic=40.586917582832456, pvalue=4.494027892786299e-55)
# Host:  11 , index:  3 overlap:  0
# Host:  11 , index:  4 overlap:  0
# Host:  11 , index:  5 overlap:  0
# Host:  11 , index:  6 overlap:  0
# Host:  11 , index:  7 overlap:  0
# Host:  11 , index:  8 overlap:  0
# Host:  11 , index:  9 overlap:  0
# Host:  11 , index:  10 overlap:  0
# Host:  11 , index:  11 overlap:  5403
# Host:  11 , index:  12 overlap:  188
#          Ttest_indResult(statistic=4.757758124835333, pvalue=4.881338279042413e-06)
# Host:  11 , index:  13 overlap:  87
#          Ttest_indResult(statistic=1.0036701069234049, pvalue=0.31949083685120006)
#          11  match with  13
# Host:  11 , index:  14 overlap:  180
#          Ttest_indResult(statistic=-0.881527579055508, pvalue=0.37950335931128343)
#          11  match with  14
# Host:  11 , index:  15 overlap:  0
# Host:  11 , index:  16 overlap:  0
# Host:  11 , index:  17 overlap:  0
# Host:  11 , index:  18 overlap:  0
# Host:  11 , index:  19 overlap:  0
# Host:  11 , index:  20 overlap:  0
# Host:  11 , index:  21 overlap:  0
# Host:  11 , index:  22 overlap:  0
# Host:  11 , index:  23 overlap:  0
# Host:  11 , index:  24 overlap:  0
# Host:  11 , index:  25 overlap:  0
# Host:  11 , index:  26 overlap:  0
# Host:  11 , index:  27 overlap:  0
# Host:  11 , index:  28 overlap:  0
# Host:  11 , index:  29 overlap:  37
#          Ttest_indResult(statistic=-0.03586838398733693, pvalue=0.9716691243404071)
#          11  match with  29
# Host:  11 , index:  30 overlap:  108
#          Ttest_indResult(statistic=-2.870803250341754, pvalue=0.005259787737088016)
# Host:  11 , index:  31 overlap:  31
#          Ttest_indResult(statistic=0.39273297890362036, pvalue=0.6986411109252291)
#          11  match with  31
# Host:  11 , index:  32 overlap:  0
# Host:  11 , index:  33 overlap:  0
# Host:  11 , index:  34 overlap:  0
# Host:  12 , index:  0 overlap:  0
# Host:  12 , index:  1 overlap:  0
# Host:  12 , index:  2 overlap:  0
# Host:  12 , index:  3 overlap:  0
# Host:  12 , index:  4 overlap:  0
# Host:  12 , index:  5 overlap:  0
# Host:  12 , index:  6 overlap:  0
# Host:  12 , index:  7 overlap:  0
# Host:  12 , index:  8 overlap:  0
# Host:  12 , index:  9 overlap:  0
# Host:  12 , index:  10 overlap:  0
# Host:  12 , index:  11 overlap:  392
#          Ttest_indResult(statistic=-4.762682082726913, pvalue=4.79451171825289e-06)
# Host:  12 , index:  12 overlap:  188
# Host:  12 , index:  13 overlap:  0
# Host:  12 , index:  14 overlap:  1
# Host:  12 , index:  15 overlap:  0
# Host:  12 , index:  16 overlap:  0
# Host:  12 , index:  17 overlap:  0
# Host:  12 , index:  18 overlap:  0
# Host:  12 , index:  19 overlap:  0
# Host:  12 , index:  20 overlap:  0
# Host:  12 , index:  21 overlap:  0
# Host:  12 , index:  22 overlap:  0
# Host:  12 , index:  23 overlap:  0
# Host:  12 , index:  24 overlap:  0
# Host:  12 , index:  25 overlap:  0
# Host:  12 , index:  26 overlap:  0
# Host:  12 , index:  27 overlap:  0
# Host:  12 , index:  28 overlap:  0
# Host:  12 , index:  29 overlap:  0
# Host:  12 , index:  30 overlap:  0
# Host:  12 , index:  31 overlap:  0
# Host:  12 , index:  32 overlap:  0
# Host:  12 , index:  33 overlap:  0
# Host:  12 , index:  34 overlap:  0
# Host:  15 , index:  0 overlap:  0
# Host:  15 , index:  1 overlap:  0
# Host:  15 , index:  2 overlap:  0
# Host:  15 , index:  3 overlap:  0
# Host:  15 , index:  4 overlap:  0
# Host:  15 , index:  5 overlap:  0
# Host:  15 , index:  6 overlap:  0
# Host:  15 , index:  7 overlap:  0
# Host:  15 , index:  8 overlap:  0
# Host:  15 , index:  9 overlap:  0
# Host:  15 , index:  10 overlap:  0
# Host:  15 , index:  11 overlap:  0
# Host:  15 , index:  12 overlap:  0
# Host:  15 , index:  13 overlap:  0
# Host:  15 , index:  14 overlap:  0
# Host:  15 , index:  15 overlap:  19039
# Host:  15 , index:  16 overlap:  1513
#          Ttest_indResult(statistic=0.6878437038502013, pvalue=0.491675430179517)
#          15  match with  16
# Host:  15 , index:  17 overlap:  317
#          Ttest_indResult(statistic=0.4658390843744554, pvalue=0.6417521213392074)
#          15  match with  17
# Host:  15 , index:  18 overlap:  0
# Host:  15 , index:  19 overlap:  0
# Host:  15 , index:  20 overlap:  0
#          Ttest_indResult(statistic=385.77509431048077, pvalue=0.0)
# Host:  15 , index:  21 overlap:  0
#          Ttest_indResult(statistic=90.73051344283087, pvalue=1.199403403940457e-102)
# Host:  15 , index:  22 overlap:  0
#          Ttest_indResult(statistic=61.00867992476007, pvalue=5.077806231792798e-34)
# Host:  15 , index:  23 overlap:  0
# Host:  15 , index:  24 overlap:  0
#          Ttest_indResult(statistic=55.29367578287372, pvalue=4.1190780355450264e-52)
# Host:  15 , index:  25 overlap:  0
# Host:  15 , index:  26 overlap:  0
# Host:  15 , index:  27 overlap:  0
# Host:  15 , index:  28 overlap:  0
# Host:  15 , index:  29 overlap:  0
# Host:  15 , index:  30 overlap:  0
# Host:  15 , index:  31 overlap:  0
# Host:  15 , index:  32 overlap:  0
#          Ttest_indResult(statistic=458.9617145662537, pvalue=0.0)
# Host:  15 , index:  33 overlap:  0
#          Ttest_indResult(statistic=294.05694345235514, pvalue=0.0)
# Host:  15 , index:  34 overlap:  0
#          Ttest_indResult(statistic=105.79125420926889, pvalue=1.0806388933314713e-84)
# Host:  18 , index:  0 overlap:  0
# Host:  18 , index:  1 overlap:  0
# Host:  18 , index:  2 overlap:  0
# Host:  18 , index:  3 overlap:  0
# Host:  18 , index:  4 overlap:  0
# Host:  18 , index:  5 overlap:  0
# Host:  18 , index:  6 overlap:  0
# Host:  18 , index:  7 overlap:  0
# Host:  18 , index:  8 overlap:  0
# Host:  18 , index:  9 overlap:  0
# Host:  18 , index:  10 overlap:  0
# Host:  18 , index:  11 overlap:  0
# Host:  18 , index:  12 overlap:  0
# Host:  18 , index:  13 overlap:  0
# Host:  18 , index:  14 overlap:  0
# Host:  18 , index:  15 overlap:  0
# Host:  18 , index:  16 overlap:  0
# Host:  18 , index:  17 overlap:  0
# Host:  18 , index:  18 overlap:  136
# Host:  18 , index:  19 overlap:  0
# Host:  18 , index:  20 overlap:  0
# Host:  18 , index:  21 overlap:  0
# Host:  18 , index:  22 overlap:  0
# Host:  18 , index:  23 overlap:  0
# Host:  18 , index:  24 overlap:  0
# Host:  18 , index:  25 overlap:  0
# Host:  18 , index:  26 overlap:  0
# Host:  18 , index:  27 overlap:  0
# Host:  18 , index:  28 overlap:  0
# Host:  18 , index:  29 overlap:  0
# Host:  18 , index:  30 overlap:  0
# Host:  18 , index:  31 overlap:  0
# Host:  18 , index:  32 overlap:  0
# Host:  18 , index:  33 overlap:  0
# Host:  18 , index:  34 overlap:  0
# Host:  19 , index:  0 overlap:  0
# Host:  19 , index:  1 overlap:  0
# Host:  19 , index:  2 overlap:  0
# Host:  19 , index:  3 overlap:  0
# Host:  19 , index:  4 overlap:  0
# Host:  19 , index:  5 overlap:  0
# Host:  19 , index:  6 overlap:  0
# Host:  19 , index:  7 overlap:  0
# Host:  19 , index:  8 overlap:  0
# Host:  19 , index:  9 overlap:  0
# Host:  19 , index:  10 overlap:  0
# Host:  19 , index:  11 overlap:  0
# Host:  19 , index:  12 overlap:  0
# Host:  19 , index:  13 overlap:  0
# Host:  19 , index:  14 overlap:  0
# Host:  19 , index:  15 overlap:  0
# Host:  19 , index:  16 overlap:  0
# Host:  19 , index:  17 overlap:  0
# Host:  19 , index:  18 overlap:  0
# Host:  19 , index:  19 overlap:  126
# Host:  19 , index:  20 overlap:  0
# Host:  19 , index:  21 overlap:  0
# Host:  19 , index:  22 overlap:  0
# Host:  19 , index:  23 overlap:  0
# Host:  19 , index:  24 overlap:  0
# Host:  19 , index:  25 overlap:  0
# Host:  19 , index:  26 overlap:  0
# Host:  19 , index:  27 overlap:  0
# Host:  19 , index:  28 overlap:  0
# Host:  19 , index:  29 overlap:  0
# Host:  19 , index:  30 overlap:  0
# Host:  19 , index:  31 overlap:  0
# Host:  19 , index:  32 overlap:  0
# Host:  19 , index:  33 overlap:  0
# Host:  19 , index:  34 overlap:  0
# Host:  20 , index:  0 overlap:  0
# Host:  20 , index:  1 overlap:  0
# Host:  20 , index:  2 overlap:  0
# Host:  20 , index:  3 overlap:  0
# Host:  20 , index:  4 overlap:  0
# Host:  20 , index:  5 overlap:  0
# Host:  20 , index:  6 overlap:  0
# Host:  20 , index:  7 overlap:  0
# Host:  20 , index:  8 overlap:  0
# Host:  20 , index:  9 overlap:  0
# Host:  20 , index:  10 overlap:  0
# Host:  20 , index:  11 overlap:  0
# Host:  20 , index:  12 overlap:  0
# Host:  20 , index:  13 overlap:  0
# Host:  20 , index:  14 overlap:  0
# Host:  20 , index:  15 overlap:  0
#          Ttest_indResult(statistic=-385.77509431048077, pvalue=0.0)
# Host:  20 , index:  16 overlap:  0
# Host:  20 , index:  17 overlap:  0
# Host:  20 , index:  18 overlap:  0
# Host:  20 , index:  19 overlap:  0
# Host:  20 , index:  20 overlap:  2799
# Host:  20 , index:  21 overlap:  150
#          Ttest_indResult(statistic=0.019123891455360448, pvalue=0.9847752772810101)
#          20  match with  21
# Host:  20 , index:  22 overlap:  46
#          Ttest_indResult(statistic=-0.13595596655212136, pvalue=0.8926994363785096)
#          20  match with  22
# Host:  20 , index:  23 overlap:  0
# Host:  20 , index:  24 overlap:  0
# Host:  20 , index:  25 overlap:  0
# Host:  20 , index:  26 overlap:  0
# Host:  20 , index:  27 overlap:  0
# Host:  20 , index:  28 overlap:  0
# Host:  20 , index:  29 overlap:  0
# Host:  20 , index:  30 overlap:  0
# Host:  20 , index:  31 overlap:  0
# Host:  20 , index:  32 overlap:  0
#          Ttest_indResult(statistic=-83.66318741388201, pvalue=0.0)
# Host:  20 , index:  33 overlap:  0
#          Ttest_indResult(statistic=-72.88341283481695, pvalue=0.0)
# Host:  20 , index:  34 overlap:  0
# Host:  23 , index:  0 overlap:  0
# Host:  23 , index:  1 overlap:  0
# Host:  23 , index:  2 overlap:  0
# Host:  23 , index:  3 overlap:  0
# Host:  23 , index:  4 overlap:  0
# Host:  23 , index:  5 overlap:  0
# Host:  23 , index:  6 overlap:  0
# Host:  23 , index:  7 overlap:  0
# Host:  23 , index:  8 overlap:  0
# Host:  23 , index:  9 overlap:  0
# Host:  23 , index:  10 overlap:  0
# Host:  23 , index:  11 overlap:  0
# Host:  23 , index:  12 overlap:  0
# Host:  23 , index:  13 overlap:  0
# Host:  23 , index:  14 overlap:  0
# Host:  23 , index:  15 overlap:  0
# Host:  23 , index:  16 overlap:  0
# Host:  23 , index:  17 overlap:  0
# Host:  23 , index:  18 overlap:  0
# Host:  23 , index:  19 overlap:  0
# Host:  23 , index:  20 overlap:  0
# Host:  23 , index:  21 overlap:  0
# Host:  23 , index:  22 overlap:  0
# Host:  23 , index:  23 overlap:  107
# Host:  23 , index:  24 overlap:  0
# Host:  23 , index:  25 overlap:  0
# Host:  23 , index:  26 overlap:  0
# Host:  23 , index:  27 overlap:  0
# Host:  23 , index:  28 overlap:  0
# Host:  23 , index:  29 overlap:  0
# Host:  23 , index:  30 overlap:  0
# Host:  23 , index:  31 overlap:  0
# Host:  23 , index:  32 overlap:  0
# Host:  23 , index:  33 overlap:  0
# Host:  23 , index:  34 overlap:  0
# Host:  24 , index:  0 overlap:  0
# Host:  24 , index:  1 overlap:  0
# Host:  24 , index:  2 overlap:  0
# Host:  24 , index:  3 overlap:  0
# Host:  24 , index:  4 overlap:  0
# Host:  24 , index:  5 overlap:  0
# Host:  24 , index:  6 overlap:  0
# Host:  24 , index:  7 overlap:  0
# Host:  24 , index:  8 overlap:  0
# Host:  24 , index:  9 overlap:  0
# Host:  24 , index:  10 overlap:  0
# Host:  24 , index:  11 overlap:  0
# Host:  24 , index:  12 overlap:  0
# Host:  24 , index:  13 overlap:  0
# Host:  24 , index:  14 overlap:  0
# Host:  24 , index:  15 overlap:  0
#          Ttest_indResult(statistic=-55.29367578287372, pvalue=4.1190780355450264e-52)
# Host:  24 , index:  16 overlap:  0
# Host:  24 , index:  17 overlap:  0
# Host:  24 , index:  18 overlap:  0
# Host:  24 , index:  19 overlap:  0
# Host:  24 , index:  20 overlap:  0
# Host:  24 , index:  21 overlap:  0
# Host:  24 , index:  22 overlap:  0
# Host:  24 , index:  23 overlap:  0
# Host:  24 , index:  24 overlap:  86
# Host:  24 , index:  25 overlap:  0
# Host:  24 , index:  26 overlap:  0
# Host:  24 , index:  27 overlap:  0
# Host:  24 , index:  28 overlap:  0
# Host:  24 , index:  29 overlap:  0
# Host:  24 , index:  30 overlap:  0
# Host:  24 , index:  31 overlap:  0
# Host:  24 , index:  32 overlap:  0
# Host:  24 , index:  33 overlap:  0
# Host:  24 , index:  34 overlap:  0
# Host:  25 , index:  0 overlap:  0
# Host:  25 , index:  1 overlap:  0
# Host:  25 , index:  2 overlap:  0
# Host:  25 , index:  3 overlap:  0
# Host:  25 , index:  4 overlap:  0
# Host:  25 , index:  5 overlap:  0
# Host:  25 , index:  6 overlap:  0
# Host:  25 , index:  7 overlap:  0
# Host:  25 , index:  8 overlap:  0
# Host:  25 , index:  9 overlap:  0
# Host:  25 , index:  10 overlap:  0
# Host:  25 , index:  11 overlap:  0
# Host:  25 , index:  12 overlap:  0
# Host:  25 , index:  13 overlap:  0
# Host:  25 , index:  14 overlap:  0
# Host:  25 , index:  15 overlap:  0
# Host:  25 , index:  16 overlap:  0
# Host:  25 , index:  17 overlap:  0
# Host:  25 , index:  18 overlap:  0
# Host:  25 , index:  19 overlap:  0
# Host:  25 , index:  20 overlap:  0
# Host:  25 , index:  21 overlap:  0
# Host:  25 , index:  22 overlap:  0
# Host:  25 , index:  23 overlap:  0
# Host:  25 , index:  24 overlap:  0
# Host:  25 , index:  25 overlap:  89
# Host:  25 , index:  26 overlap:  0
# Host:  25 , index:  27 overlap:  0
# Host:  25 , index:  28 overlap:  0
# Host:  25 , index:  29 overlap:  0
# Host:  25 , index:  30 overlap:  0
# Host:  25 , index:  31 overlap:  0
# Host:  25 , index:  32 overlap:  0
# Host:  25 , index:  33 overlap:  0
# Host:  25 , index:  34 overlap:  0
# Host:  26 , index:  0 overlap:  0
# Host:  26 , index:  1 overlap:  0
# Host:  26 , index:  2 overlap:  0
# Host:  26 , index:  3 overlap:  0
# Host:  26 , index:  4 overlap:  0
# Host:  26 , index:  5 overlap:  0
# Host:  26 , index:  6 overlap:  0
# Host:  26 , index:  7 overlap:  0
# Host:  26 , index:  8 overlap:  0
# Host:  26 , index:  9 overlap:  0
# Host:  26 , index:  10 overlap:  0
# Host:  26 , index:  11 overlap:  0
# Host:  26 , index:  12 overlap:  0
# Host:  26 , index:  13 overlap:  0
# Host:  26 , index:  14 overlap:  0
# Host:  26 , index:  15 overlap:  0
# Host:  26 , index:  16 overlap:  0
# Host:  26 , index:  17 overlap:  0
# Host:  26 , index:  18 overlap:  0
# Host:  26 , index:  19 overlap:  0
# Host:  26 , index:  20 overlap:  0
# Host:  26 , index:  21 overlap:  0
# Host:  26 , index:  22 overlap:  0
# Host:  26 , index:  23 overlap:  0
# Host:  26 , index:  24 overlap:  0
# Host:  26 , index:  25 overlap:  0
# Host:  26 , index:  26 overlap:  56
# Host:  26 , index:  27 overlap:  0
# Host:  26 , index:  28 overlap:  0
# Host:  26 , index:  29 overlap:  0
# Host:  26 , index:  30 overlap:  0
# Host:  26 , index:  31 overlap:  0
# Host:  26 , index:  32 overlap:  0
# Host:  26 , index:  33 overlap:  0
# Host:  26 , index:  34 overlap:  0
# Host:  27 , index:  0 overlap:  0
# Host:  27 , index:  1 overlap:  0
# Host:  27 , index:  2 overlap:  0
# Host:  27 , index:  3 overlap:  0
# Host:  27 , index:  4 overlap:  0
# Host:  27 , index:  5 overlap:  0
# Host:  27 , index:  6 overlap:  0
# Host:  27 , index:  7 overlap:  0
# Host:  27 , index:  8 overlap:  0
#          Ttest_indResult(statistic=-162.12749644984572, pvalue=0.0)
# Host:  27 , index:  9 overlap:  0
# Host:  27 , index:  10 overlap:  0
# Host:  27 , index:  11 overlap:  0
# Host:  27 , index:  12 overlap:  0
# Host:  27 , index:  13 overlap:  0
# Host:  27 , index:  14 overlap:  0
# Host:  27 , index:  15 overlap:  0
# Host:  27 , index:  16 overlap:  0
# Host:  27 , index:  17 overlap:  0
# Host:  27 , index:  18 overlap:  0
# Host:  27 , index:  19 overlap:  0
# Host:  27 , index:  20 overlap:  0
# Host:  27 , index:  21 overlap:  0
# Host:  27 , index:  22 overlap:  0
# Host:  27 , index:  23 overlap:  0
# Host:  27 , index:  24 overlap:  0
# Host:  27 , index:  25 overlap:  0
# Host:  27 , index:  26 overlap:  0
# Host:  27 , index:  27 overlap:  2235
# Host:  27 , index:  28 overlap:  504
#          Ttest_indResult(statistic=-0.010857639921754614, pvalue=0.9913437099931914)
#          27  match with  28
# Host:  27 , index:  29 overlap:  0
# Host:  27 , index:  30 overlap:  0
# Host:  27 , index:  31 overlap:  0
# Host:  27 , index:  32 overlap:  0
# Host:  27 , index:  33 overlap:  0
# Host:  27 , index:  34 overlap:  0
# Host:  30 , index:  0 overlap:  0
# Host:  30 , index:  1 overlap:  0
# Host:  30 , index:  2 overlap:  0
# Host:  30 , index:  3 overlap:  0
# Host:  30 , index:  4 overlap:  0
# Host:  30 , index:  5 overlap:  0
# Host:  30 , index:  6 overlap:  0
# Host:  30 , index:  7 overlap:  0
# Host:  30 , index:  8 overlap:  0
# Host:  30 , index:  9 overlap:  0
# Host:  30 , index:  10 overlap:  0
# Host:  30 , index:  11 overlap:  216
#          Ttest_indResult(statistic=2.875108598405623, pvalue=0.005195563025868335)
# Host:  30 , index:  12 overlap:  0
# Host:  30 , index:  13 overlap:  0
# Host:  30 , index:  14 overlap:  0
# Host:  30 , index:  15 overlap:  0
# Host:  30 , index:  16 overlap:  0
# Host:  30 , index:  17 overlap:  0
# Host:  30 , index:  18 overlap:  0
# Host:  30 , index:  19 overlap:  0
# Host:  30 , index:  20 overlap:  0
# Host:  30 , index:  21 overlap:  0
# Host:  30 , index:  22 overlap:  0
# Host:  30 , index:  23 overlap:  0
# Host:  30 , index:  24 overlap:  0
# Host:  30 , index:  25 overlap:  0
# Host:  30 , index:  26 overlap:  0
# Host:  30 , index:  27 overlap:  0
# Host:  30 , index:  28 overlap:  0
# Host:  30 , index:  29 overlap:  0
# Host:  30 , index:  30 overlap:  108
# Host:  30 , index:  31 overlap:  0
# Host:  30 , index:  32 overlap:  0
# Host:  30 , index:  33 overlap:  0
# Host:  30 , index:  34 overlap:  0
# Host:  32 , index:  0 overlap:  0
# Host:  32 , index:  1 overlap:  0
# Host:  32 , index:  2 overlap:  0
# Host:  32 , index:  3 overlap:  0
# Host:  32 , index:  4 overlap:  0
# Host:  32 , index:  5 overlap:  0
# Host:  32 , index:  6 overlap:  0
# Host:  32 , index:  7 overlap:  0
# Host:  32 , index:  8 overlap:  0
# Host:  32 , index:  9 overlap:  0
# Host:  32 , index:  10 overlap:  0
# Host:  32 , index:  11 overlap:  0
# Host:  32 , index:  12 overlap:  0
# Host:  32 , index:  13 overlap:  0
# Host:  32 , index:  14 overlap:  0
# Host:  32 , index:  15 overlap:  0
#          Ttest_indResult(statistic=-458.9617145662537, pvalue=0.0)
# Host:  32 , index:  16 overlap:  0
# Host:  32 , index:  17 overlap:  0
# Host:  32 , index:  18 overlap:  0
# Host:  32 , index:  19 overlap:  0
# Host:  32 , index:  20 overlap:  0
#          Ttest_indResult(statistic=83.66318741388201, pvalue=0.0)
# Host:  32 , index:  21 overlap:  0
# Host:  32 , index:  22 overlap:  0
# Host:  32 , index:  23 overlap:  0
# Host:  32 , index:  24 overlap:  0
# Host:  32 , index:  25 overlap:  0
# Host:  32 , index:  26 overlap:  0
# Host:  32 , index:  27 overlap:  0
# Host:  32 , index:  28 overlap:  0
# Host:  32 , index:  29 overlap:  0
# Host:  32 , index:  30 overlap:  0
# Host:  32 , index:  31 overlap:  0
# Host:  32 , index:  32 overlap:  1863
# Host:  32 , index:  33 overlap:  913
#          Ttest_indResult(statistic=-5.631083633808506, pvalue=2.2856455716250977e-08)
# Host:  32 , index:  34 overlap:  108
#          Ttest_indResult(statistic=-2.3025264794552474, pvalue=0.023905010452752652)
# Host:  33 , index:  0 overlap:  0
# Host:  33 , index:  1 overlap:  0
# Host:  33 , index:  2 overlap:  0
# Host:  33 , index:  3 overlap:  0
# Host:  33 , index:  4 overlap:  0
# Host:  33 , index:  5 overlap:  0
# Host:  33 , index:  6 overlap:  0
# Host:  33 , index:  7 overlap:  0
# Host:  33 , index:  8 overlap:  0
# Host:  33 , index:  9 overlap:  0
# Host:  33 , index:  10 overlap:  0
# Host:  33 , index:  11 overlap:  0
# Host:  33 , index:  12 overlap:  0
# Host:  33 , index:  13 overlap:  0
# Host:  33 , index:  14 overlap:  0
# Host:  33 , index:  15 overlap:  0
#          Ttest_indResult(statistic=-294.05694345235514, pvalue=0.0)
# Host:  33 , index:  16 overlap:  0
# Host:  33 , index:  17 overlap:  0
# Host:  33 , index:  18 overlap:  0
# Host:  33 , index:  19 overlap:  0
# Host:  33 , index:  20 overlap:  0
#          Ttest_indResult(statistic=72.88341283481695, pvalue=0.0)
# Host:  33 , index:  21 overlap:  0
# Host:  33 , index:  22 overlap:  0
# Host:  33 , index:  23 overlap:  0
# Host:  33 , index:  24 overlap:  0
# Host:  33 , index:  25 overlap:  0
# Host:  33 , index:  26 overlap:  0
# Host:  33 , index:  27 overlap:  0
# Host:  33 , index:  28 overlap:  0
# Host:  33 , index:  29 overlap:  0
# Host:  33 , index:  30 overlap:  0
# Host:  33 , index:  31 overlap:  0
# Host:  33 , index:  32 overlap:  1826
#          Ttest_indResult(statistic=5.631083633808506, pvalue=2.2856455716250977e-08)
# Host:  33 , index:  33 overlap:  913
# Host:  33 , index:  34 overlap:  108
#          Ttest_indResult(statistic=-0.12430805180584599, pvalue=0.9013428902637942)
#          33  match with  34
# Host:  0 , index:  0 overlap:  2755
# Host:  0 , index:  1 overlap:  122
#          Ttest_indResult(statistic=35.89001826784831, pvalue=3.5293090255419566e-51)
# Host:  0 , index:  2 overlap:  0
# Host:  0 , index:  3 overlap:  0
# Host:  0 , index:  4 overlap:  0
#          Ttest_indResult(statistic=-20.88754965245679, pvalue=6.937222965063594e-93)
# Host:  0 , index:  5 overlap:  0
# Host:  0 , index:  6 overlap:  0
# Host:  0 , index:  7 overlap:  0
# Host:  0 , index:  8 overlap:  0
# Host:  0 , index:  9 overlap:  0
# Host:  0 , index:  10 overlap:  0
# Host:  0 , index:  11 overlap:  0
# Host:  0 , index:  12 overlap:  0
# Host:  0 , index:  13 overlap:  0
# Host:  0 , index:  14 overlap:  0
# Host:  0 , index:  15 overlap:  0
# Host:  0 , index:  16 overlap:  0
# Host:  0 , index:  17 overlap:  0
# Host:  1 , index:  0 overlap:  36
#          Ttest_indResult(statistic=-35.89001826784831, pvalue=3.5293090255419566e-51)
# Host:  1 , index:  1 overlap:  124
# Host:  1 , index:  2 overlap:  0
# Host:  1 , index:  3 overlap:  0
# Host:  1 , index:  4 overlap:  0
#          Ttest_indResult(statistic=-40.61876075844661, pvalue=5.5008777145766254e-55)
# Host:  1 , index:  5 overlap:  0
# Host:  1 , index:  6 overlap:  0
# Host:  1 , index:  7 overlap:  0
# Host:  1 , index:  8 overlap:  0
# Host:  1 , index:  9 overlap:  0
# Host:  1 , index:  10 overlap:  0
# Host:  1 , index:  11 overlap:  0
# Host:  1 , index:  12 overlap:  0
# Host:  1 , index:  13 overlap:  0
# Host:  1 , index:  14 overlap:  0
# Host:  1 , index:  15 overlap:  0
# Host:  1 , index:  16 overlap:  0
# Host:  1 , index:  17 overlap:  0
# Host:  2 , index:  0 overlap:  0
# Host:  2 , index:  1 overlap:  0
# Host:  2 , index:  2 overlap:  10364
# Host:  2 , index:  3 overlap:  0
# Host:  2 , index:  4 overlap:  0
# Host:  2 , index:  5 overlap:  0
# Host:  2 , index:  6 overlap:  0
# Host:  2 , index:  7 overlap:  0
# Host:  2 , index:  8 overlap:  0
# Host:  2 , index:  9 overlap:  0
# Host:  2 , index:  10 overlap:  0
# Host:  2 , index:  11 overlap:  0
# Host:  2 , index:  12 overlap:  0
# Host:  2 , index:  13 overlap:  0
# Host:  2 , index:  14 overlap:  0
# Host:  2 , index:  15 overlap:  0
# Host:  2 , index:  16 overlap:  0
# Host:  2 , index:  17 overlap:  0
# Host:  3 , index:  0 overlap:  0
# Host:  3 , index:  1 overlap:  0
# Host:  3 , index:  2 overlap:  0
# Host:  3 , index:  3 overlap:  5739
# Host:  3 , index:  4 overlap:  0
# Host:  3 , index:  5 overlap:  0
# Host:  3 , index:  6 overlap:  0
# Host:  3 , index:  7 overlap:  0
# Host:  3 , index:  8 overlap:  0
# Host:  3 , index:  9 overlap:  0
# Host:  3 , index:  10 overlap:  0
# Host:  3 , index:  11 overlap:  0
# Host:  3 , index:  12 overlap:  0
# Host:  3 , index:  13 overlap:  0
# Host:  3 , index:  14 overlap:  0
#          Ttest_indResult(statistic=175.49098809111734, pvalue=0.0)
# Host:  3 , index:  15 overlap:  0
# Host:  3 , index:  16 overlap:  0
# Host:  3 , index:  17 overlap:  0
# Host:  4 , index:  0 overlap:  0
#          Ttest_indResult(statistic=20.88754965245679, pvalue=6.937222965063594e-93)
# Host:  4 , index:  1 overlap:  0
#          Ttest_indResult(statistic=40.61876075844661, pvalue=5.5008777145766254e-55)
# Host:  4 , index:  2 overlap:  0
# Host:  4 , index:  3 overlap:  0
# Host:  4 , index:  4 overlap:  6073
# Host:  4 , index:  5 overlap:  188
#          Ttest_indResult(statistic=4.762682082726913, pvalue=4.79451171825289e-06)
# Host:  4 , index:  6 overlap:  0
# Host:  4 , index:  7 overlap:  0
# Host:  4 , index:  8 overlap:  0
# Host:  4 , index:  9 overlap:  0
# Host:  4 , index:  10 overlap:  0
# Host:  4 , index:  11 overlap:  0
# Host:  4 , index:  12 overlap:  0
# Host:  4 , index:  13 overlap:  0
# Host:  4 , index:  14 overlap:  0
# Host:  4 , index:  15 overlap:  108
#          Ttest_indResult(statistic=-2.875108598405623, pvalue=0.005195563025868335)
# Host:  4 , index:  16 overlap:  0
# Host:  4 , index:  17 overlap:  0
# Host:  5 , index:  0 overlap:  0
# Host:  5 , index:  1 overlap:  0
# Host:  5 , index:  2 overlap:  0
# Host:  5 , index:  3 overlap:  0
# Host:  5 , index:  4 overlap:  392
#          Ttest_indResult(statistic=-4.762682082726913, pvalue=4.79451171825289e-06)
# Host:  5 , index:  5 overlap:  188
# Host:  5 , index:  6 overlap:  0
# Host:  5 , index:  7 overlap:  0
# Host:  5 , index:  8 overlap:  0
# Host:  5 , index:  9 overlap:  0
# Host:  5 , index:  10 overlap:  0
# Host:  5 , index:  11 overlap:  0
# Host:  5 , index:  12 overlap:  0
# Host:  5 , index:  13 overlap:  0
# Host:  5 , index:  14 overlap:  0
# Host:  5 , index:  15 overlap:  0
# Host:  5 , index:  16 overlap:  0
# Host:  5 , index:  17 overlap:  0
# Host:  6 , index:  0 overlap:  0
# Host:  6 , index:  1 overlap:  0
# Host:  6 , index:  2 overlap:  0
# Host:  6 , index:  3 overlap:  0
# Host:  6 , index:  4 overlap:  0
# Host:  6 , index:  5 overlap:  0
# Host:  6 , index:  6 overlap:  22699
# Host:  6 , index:  7 overlap:  0
# Host:  6 , index:  8 overlap:  0
# Host:  6 , index:  9 overlap:  0
#          Ttest_indResult(statistic=397.2643690871551, pvalue=0.0)
# Host:  6 , index:  10 overlap:  0
# Host:  6 , index:  11 overlap:  0
#          Ttest_indResult(statistic=55.29367578287372, pvalue=4.1190780355450264e-52)
# Host:  6 , index:  12 overlap:  0
# Host:  6 , index:  13 overlap:  0
# Host:  6 , index:  14 overlap:  0
# Host:  6 , index:  15 overlap:  0
# Host:  6 , index:  16 overlap:  0
#          Ttest_indResult(statistic=458.9617145662537, pvalue=0.0)
# Host:  6 , index:  17 overlap:  0
#          Ttest_indResult(statistic=308.43626962279126, pvalue=0.0)
# Host:  7 , index:  0 overlap:  0
# Host:  7 , index:  1 overlap:  0
# Host:  7 , index:  2 overlap:  0
# Host:  7 , index:  3 overlap:  0
# Host:  7 , index:  4 overlap:  0
# Host:  7 , index:  5 overlap:  0
# Host:  7 , index:  6 overlap:  0
# Host:  7 , index:  7 overlap:  136
# Host:  7 , index:  8 overlap:  0
# Host:  7 , index:  9 overlap:  0
# Host:  7 , index:  10 overlap:  0
# Host:  7 , index:  11 overlap:  0
# Host:  7 , index:  12 overlap:  0
# Host:  7 , index:  13 overlap:  0
# Host:  7 , index:  14 overlap:  0
# Host:  7 , index:  15 overlap:  0
# Host:  7 , index:  16 overlap:  0
# Host:  7 , index:  17 overlap:  0
# Host:  8 , index:  0 overlap:  0
# Host:  8 , index:  1 overlap:  0
# Host:  8 , index:  2 overlap:  0
# Host:  8 , index:  3 overlap:  0
# Host:  8 , index:  4 overlap:  0
# Host:  8 , index:  5 overlap:  0
# Host:  8 , index:  6 overlap:  0
# Host:  8 , index:  7 overlap:  0
# Host:  8 , index:  8 overlap:  126
# Host:  8 , index:  9 overlap:  0
# Host:  8 , index:  10 overlap:  0
# Host:  8 , index:  11 overlap:  0
# Host:  8 , index:  12 overlap:  0
# Host:  8 , index:  13 overlap:  0
# Host:  8 , index:  14 overlap:  0
# Host:  8 , index:  15 overlap:  0
# Host:  8 , index:  16 overlap:  0
# Host:  8 , index:  17 overlap:  0
# Host:  9 , index:  0 overlap:  0
# Host:  9 , index:  1 overlap:  0
# Host:  9 , index:  2 overlap:  0
# Host:  9 , index:  3 overlap:  0
# Host:  9 , index:  4 overlap:  0
# Host:  9 , index:  5 overlap:  0
# Host:  9 , index:  6 overlap:  0
#          Ttest_indResult(statistic=-397.2643690871551, pvalue=0.0)
# Host:  9 , index:  7 overlap:  0
# Host:  9 , index:  8 overlap:  0
# Host:  9 , index:  9 overlap:  3191
# Host:  9 , index:  10 overlap:  0
# Host:  9 , index:  11 overlap:  0
# Host:  9 , index:  12 overlap:  0
# Host:  9 , index:  13 overlap:  0
# Host:  9 , index:  14 overlap:  0
# Host:  9 , index:  15 overlap:  0
# Host:  9 , index:  16 overlap:  0
#          Ttest_indResult(statistic=-83.66318741388201, pvalue=0.0)
# Host:  9 , index:  17 overlap:  0
#          Ttest_indResult(statistic=-74.94435119493156, pvalue=0.0)
# Host:  10 , index:  0 overlap:  0
# Host:  10 , index:  1 overlap:  0
# Host:  10 , index:  2 overlap:  0
# Host:  10 , index:  3 overlap:  0
# Host:  10 , index:  4 overlap:  0
# Host:  10 , index:  5 overlap:  0
# Host:  10 , index:  6 overlap:  0
# Host:  10 , index:  7 overlap:  0
# Host:  10 , index:  8 overlap:  0
# Host:  10 , index:  9 overlap:  0
# Host:  10 , index:  10 overlap:  107
# Host:  10 , index:  11 overlap:  0
# Host:  10 , index:  12 overlap:  0
# Host:  10 , index:  13 overlap:  0
# Host:  10 , index:  14 overlap:  0
# Host:  10 , index:  15 overlap:  0
# Host:  10 , index:  16 overlap:  0
# Host:  10 , index:  17 overlap:  0
# Host:  11 , index:  0 overlap:  0
# Host:  11 , index:  1 overlap:  0
# Host:  11 , index:  2 overlap:  0
# Host:  11 , index:  3 overlap:  0
# Host:  11 , index:  4 overlap:  0
# Host:  11 , index:  5 overlap:  0
# Host:  11 , index:  6 overlap:  0
#          Ttest_indResult(statistic=-55.29367578287372, pvalue=4.1190780355450264e-52)
# Host:  11 , index:  7 overlap:  0
# Host:  11 , index:  8 overlap:  0
# Host:  11 , index:  9 overlap:  0
# Host:  11 , index:  10 overlap:  0
# Host:  11 , index:  11 overlap:  86
# Host:  11 , index:  12 overlap:  0
# Host:  11 , index:  13 overlap:  0
# Host:  11 , index:  14 overlap:  0
# Host:  11 , index:  15 overlap:  0
# Host:  11 , index:  16 overlap:  0
# Host:  11 , index:  17 overlap:  0
# Host:  12 , index:  0 overlap:  0
# Host:  12 , index:  1 overlap:  0
# Host:  12 , index:  2 overlap:  0
# Host:  12 , index:  3 overlap:  0
# Host:  12 , index:  4 overlap:  0
# Host:  12 , index:  5 overlap:  0
# Host:  12 , index:  6 overlap:  0
# Host:  12 , index:  7 overlap:  0
# Host:  12 , index:  8 overlap:  0
# Host:  12 , index:  9 overlap:  0
# Host:  12 , index:  10 overlap:  0
# Host:  12 , index:  11 overlap:  0
# Host:  12 , index:  12 overlap:  89
# Host:  12 , index:  13 overlap:  0
# Host:  12 , index:  14 overlap:  0
# Host:  12 , index:  15 overlap:  0
# Host:  12 , index:  16 overlap:  0
# Host:  12 , index:  17 overlap:  0
# Host:  13 , index:  0 overlap:  0
# Host:  13 , index:  1 overlap:  0
# Host:  13 , index:  2 overlap:  0
# Host:  13 , index:  3 overlap:  0
# Host:  13 , index:  4 overlap:  0
# Host:  13 , index:  5 overlap:  0
# Host:  13 , index:  6 overlap:  0
# Host:  13 , index:  7 overlap:  0
# Host:  13 , index:  8 overlap:  0
# Host:  13 , index:  9 overlap:  0
# Host:  13 , index:  10 overlap:  0
# Host:  13 , index:  11 overlap:  0
# Host:  13 , index:  12 overlap:  0
# Host:  13 , index:  13 overlap:  56
# Host:  13 , index:  14 overlap:  0
# Host:  13 , index:  15 overlap:  0
# Host:  13 , index:  16 overlap:  0
# Host:  13 , index:  17 overlap:  0
# Host:  14 , index:  0 overlap:  0
# Host:  14 , index:  1 overlap:  0
# Host:  14 , index:  2 overlap:  0
# Host:  14 , index:  3 overlap:  0
#          Ttest_indResult(statistic=-175.49098809111734, pvalue=0.0)
# Host:  14 , index:  4 overlap:  0
# Host:  14 , index:  5 overlap:  0
# Host:  14 , index:  6 overlap:  0
# Host:  14 , index:  7 overlap:  0
# Host:  14 , index:  8 overlap:  0
# Host:  14 , index:  9 overlap:  0
# Host:  14 , index:  10 overlap:  0
# Host:  14 , index:  11 overlap:  0
# Host:  14 , index:  12 overlap:  0
# Host:  14 , index:  13 overlap:  0
# Host:  14 , index:  14 overlap:  3243
# Host:  14 , index:  15 overlap:  0
# Host:  14 , index:  16 overlap:  0
# Host:  14 , index:  17 overlap:  0
# Host:  15 , index:  0 overlap:  0
# Host:  15 , index:  1 overlap:  0
# Host:  15 , index:  2 overlap:  0
# Host:  15 , index:  3 overlap:  0
# Host:  15 , index:  4 overlap:  216
#          Ttest_indResult(statistic=2.875108598405623, pvalue=0.005195563025868335)
# Host:  15 , index:  5 overlap:  0
# Host:  15 , index:  6 overlap:  0
# Host:  15 , index:  7 overlap:  0
# Host:  15 , index:  8 overlap:  0
# Host:  15 , index:  9 overlap:  0
# Host:  15 , index:  10 overlap:  0
# Host:  15 , index:  11 overlap:  0
# Host:  15 , index:  12 overlap:  0
# Host:  15 , index:  13 overlap:  0
# Host:  15 , index:  14 overlap:  0
# Host:  15 , index:  15 overlap:  108
# Host:  15 , index:  16 overlap:  0
# Host:  15 , index:  17 overlap:  0
# Host:  16 , index:  0 overlap:  0
# Host:  16 , index:  1 overlap:  0
# Host:  16 , index:  2 overlap:  0
# Host:  16 , index:  3 overlap:  0
# Host:  16 , index:  4 overlap:  0
# Host:  16 , index:  5 overlap:  0
# Host:  16 , index:  6 overlap:  0
#          Ttest_indResult(statistic=-458.9617145662537, pvalue=0.0)
# Host:  16 , index:  7 overlap:  0
# Host:  16 , index:  8 overlap:  0
# Host:  16 , index:  9 overlap:  0
#          Ttest_indResult(statistic=83.66318741388201, pvalue=0.0)
# Host:  16 , index:  10 overlap:  0
# Host:  16 , index:  11 overlap:  0
# Host:  16 , index:  12 overlap:  0
# Host:  16 , index:  13 overlap:  0
# Host:  16 , index:  14 overlap:  0
# Host:  16 , index:  15 overlap:  0
# Host:  16 , index:  16 overlap:  1863
# Host:  16 , index:  17 overlap:  1129
#          Ttest_indResult(statistic=-5.900226472620147, pvalue=4.676135072626732e-09)
# Host:  17 , index:  0 overlap:  0
# Host:  17 , index:  1 overlap:  0
# Host:  17 , index:  2 overlap:  0
# Host:  17 , index:  3 overlap:  0
# Host:  17 , index:  4 overlap:  0
# Host:  17 , index:  5 overlap:  0
# Host:  17 , index:  6 overlap:  0
#          Ttest_indResult(statistic=-308.43626962279126, pvalue=0.0)
# Host:  17 , index:  7 overlap:  0
# Host:  17 , index:  8 overlap:  0
# Host:  17 , index:  9 overlap:  0
#          Ttest_indResult(statistic=74.94435119493156, pvalue=0.0)
# Host:  17 , index:  10 overlap:  0
# Host:  17 , index:  11 overlap:  0
# Host:  17 , index:  12 overlap:  0
# Host:  17 , index:  13 overlap:  0
# Host:  17 , index:  14 overlap:  0
# Host:  17 , index:  15 overlap:  0
# Host:  17 , index:  16 overlap:  1826
#          Ttest_indResult(statistic=5.900226472620147, pvalue=4.676135072626732e-09)
# Host:  17 , index:  17 overlap:  1129

# %% [markdown]
# ## Plots

# %%
# Plot benchmark
BMplot = mpl.pyplot.figure()
### Sky map cluster plot
ax1 = BMplot.add_subplot(1, 2, 1)
plt.grid()
mpl.pyplot.scatter(BenchMarktHRx, BenchMark[:,1])
ax1 = BMplot.add_subplot(1, 2, 2)
plt.grid()
mpl.pyplot.scatter(BenchMarktHRx, BenchMarktHRy)

# %%
# Plot subClusters
subClusterPlots=[]
for i, subCluster in enumerate(subClusters):
    subClusterPlots.append(mpl.pyplot.figure())
    ### Sky map cluster plot
    ax1 = subClusterPlots[-1].add_subplot(1, 3, 1)
    plt.grid()
    mpl.pyplot.scatter(subCluster[:,1], subCluster[:,2], c= subCluster[:,5], cmap= 'bwr', marker ='x')
    ### HR diagram cluster plot
    ax2 = subClusterPlots[-1].add_subplot(1, 3, 2)
    plt.grid()
    mpl.pyplot.scatter(subCluster[:,3],subCluster[:,4], marker = 'x', color='blue')
 
    ax3 = subClusterPlots[-1].add_subplot(1, 3, 3)
    
    mpl.pyplot.scatter(subClusterMS[i][:,0],subClusterMS[i][:,1], marker = '+', color='green')
    # ax3.fill(X_plot, subCluster[2], fc="#AAAAFF")
    # ax3.set_xlim(min(farPoints_floats[:,5]),2)
    ax3.set_ylim(-10,-2)
    plt.grid()
plt.show()

# %%
# Plot clusters
clusterPlots=[]
for i, cluster in enumerate(clusters):
    clusterPlots.append(mpl.pyplot.figure())
    ### Sky map cluster plot
    ax1 = clusterPlots[-1].add_subplot(1, 3, 1)
    plt.grid()
    mpl.pyplot.scatter(cluster[:,1], cluster[:,2], c= cluster[:,5], cmap= 'bwr', marker ='x')
    ### HR diagram cluster plot
    ax2 = clusterPlots[-1].add_subplot(1, 3, 2)
    plt.grid()
    mpl.pyplot.scatter(cluster[:,3],cluster[:,4], marker = 'x', color='blue')
    ax3 = clusterPlots[-1].add_subplot(1, 3, 3)
    mpl.pyplot.scatter(clusterMS[i][:,0],clusterMS[i][:,1], marker = '+', color='green')
    ax3.set_ylim(-10,-2)
    plt.grid()
plt.show()
