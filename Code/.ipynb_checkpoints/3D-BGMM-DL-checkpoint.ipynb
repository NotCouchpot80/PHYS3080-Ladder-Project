# %% [markdown]
# ## Project setup

# %%
# import required libraries
import os
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.table import Table
import glob
import warnings
from sklearn import mixture
from sklearn.neighbors import KernelDensity
import itertools
import seaborn as sns
from sklearn.utils.fixes import parse_version

# 
# configure notebook for plotting
# %pylab inline --no-import-all 
mpl.style.use('seaborn-colorblind') # colourblind-friendly colour scheme
colours = mpl.rcParams['axes.prop_cycle'].by_key()['color'] # allows access to colours
# subsequent lines default plot settings
matplotlib.rcParams['image.origin'] = 'lower'
matplotlib.rcParams['figure.figsize']=(20,5)  
matplotlib.rcParams['font.size']=16    
matplotlib.rcParams['savefig.dpi']= 300   
warnings.filterwarnings('ignore')

# functions
def in_hull(p, hull):
    # """
    # code from https://stackoverflow.com/questions/16750618/whats-an-efficient-way-to-find-if-a-point-lies-in-the-convex-hull-of-a-point-cl, by user Juh_
    # Test if points in `p` are in `hull`

    # `p` should be a `NxK` coordinates of `N` points in `K` dimensions
    # `hull` is either a scipy.spatial.Delaunay object or the `MxK` array of the 
    # coordinates of `M` points in `K`dimensions for which Delaunay triangulation
    # will be computed
    # """
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)

    return hull.find_simplex(p)>=0
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Initial data entry

# %%
# import data from Data directory
allPointsFiles = glob.glob('../Data/*/*/points.txt')
allFuzzyFiles = glob.glob('../Data/*/*/fuzzy.txt')
allVaryingPointFiles = glob.glob('../Data/*/*/P*.csv')
allXrayFiles = glob.glob('../Data/XrayFlash.txt')

# initiate initial variables
farPoints = []
midPoints = []
closePoints = []
allPoints = []
variablePoints = []
xRayPoints = []
fuzzies = []
name2ID = []
# initial loading and sorting
# points (row = [name, x, y, distance, HRx, HRy, RV])

# initiate parameters
upperParallaxLimit = 0.006
lowerParallaxLimit = 0.005
ID=100000
# sort the points
for j, pointsFile in enumerate(allPointsFiles):
    try:
        this = Table.read(pointsFile,format='ascii')
        thispar = this['par']
        thism0, thism1, thism2 = (np.log10(this['flux1']), 
                                  np.log10(this['flux2']), 
                                  np.log10(this['flux3']))
        thiscolour = thism2-thism0
        # transform coords onto "sky net" based on file path and store in numpy array          
        if pointsFile.rfind('Up')!=-1:
            points = np.array([this['name'], this['y'], -this['x']+90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Front')!=-1:
            points = np.array([this['name'], this['y']-90, -this['x']+90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Right')!=-1:
            points = np.array([this['name'], this['x'], this['y'], thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Back')!=-1:
            points = np.array([this['name'], this['x']+90, this['y'], thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Left')!=-1:
            points = np.array([this['name'], this['y']-90, -this['x']+180, thispar, thiscolour, thism1, this['rv']]).T.tolist()
        elif pointsFile.rfind('Down')!=-1:
            points = np.array([this['name'], this['y'], -this['x']-90, thispar, thiscolour, thism1, this['rv']]).T.tolist()
            
        # sort into close and far
        for point in points:
            ID=ID+1
            name2ID.append([point[0],ID])
            point[0]=str(ID)
            if float(point[3]) > upperParallaxLimit:
                closePoints.append(point)
            elif float(point[3]) <= lowerParallaxLimit:# value chosen to minimize clusters being assigned to mid distance
                farPoints.append(point)   
            else:
                midPoints.append(point)  
    except Exception as e:
        print('Failed point sorting: '+ str(e))
        pass
closePoints=np.array(closePoints).astype(np.float)
midPoints=np.array(midPoints).astype(np.float).astype(np.float)
farPoints=np.array(farPoints).astype(np.float)
allPoints=np.concatenate((closePoints, midPoints, farPoints),axis=0).astype(np.float)
name2ID=np.array(name2ID)
# fuzzies (row = [name, x, y, flux1, flux2, flux3, width, RV])
for j, fuzzyFile in enumerate(allFuzzyFiles):
    fuzzy=[]
    try:
        this = Table.read(fuzzyFile,format='ascii')
        # transform coords onto "sky net" based on file path and store in numpy array          
        if pointsFile.rfind('Up')!=-1:
            fuzzy = np.array([this['name'], this['y'], -this['x']+90,this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Front')!=-1:
            fuzzy = np.array([this['name'], this['y']-90, -this['x']+90, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Right')!=-1:
            fuzzy = np.array([this['name'], this['x'], this['y'], this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Back')!=-1:
            fuzzy = np.array([this['name'], this['x']+90, this['y'], this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Left')!=-1:
            fuzzy = np.array([this['name'], this['y']-90, -this['x']+180, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
        elif pointsFile.rfind('Down')!=-1:
            fuzzy = np.array([this['name'], this['y'], -this['x']-90, this['flux1'], this['flux2'],this['flux3'], this['width'], this['rv']]).T.tolist()
    except:
        pass
    fuzzies.append(fuzzy)
fuzzies = np.array(fuzzies).astype(np.float)

# Xray flashes (row = [x, y, luminosity])
for j, XrayFiles in enumerate(allXrayFiles):
    Xrays = []
    try:
        this = Table.read(XrayFiles,format='ascii')
        for line in this:
            # transform coords onto "sky net" based on file path and store in numpy array          
            if line['Camera']==('Up'):
                Xrays = np.array([line['y'], -line['x']+90, line['mag']]).T.tolist()
            elif line['Camera']==('Front'):
                Xrays = np.array([ line['y']-90, -line['x']+90, line['mag']]).T.tolist()
            elif line['Camera']==('Right'):
                Xrays = np.array([ line['x'], line['y'], line['mag']]).T.tolist()
            elif line['Camera']==('Back'):
                Xrays = np.array([line['x']+90, line['y'], line['mag']]).T.tolist()
            elif line['Camera']==('Left'):
                Xrays = np.array([ line['y']-90, -line['x']+180, line['mag']]).T.tolist()
            elif line['Camera']==('Down'):
                Xrays = np.array([ line['y'], -line['x']-90, line['mag']]).T.tolist()

            xRayPoints.append(Xrays)
    except Exception as e:
        logger.error('Failed: '+ str(e))
        pass
xRayflashes=np.array(xRayPoints).astype(np.float)

# Variable points (row = [name, x, y, dist, HRx, HRy, abs mag, RV, variable data])
for j, varsFile in enumerate(allVaryingPointFiles):
    
    try:
        thisVar = np.array(Table.read(varsFile,format='ascii'))
        name = varsFile[-10:-4]
        pointID=name2ID[name2ID[:,0]==name,1][0]
        basicData=allPoints[(allPoints[:,0]==pointID.astype(np.float)),:]
        variablePoint=np.array([basicData[0,0],basicData[0,1],basicData[0,2],basicData[0,3],basicData[0,4],basicData[0,5],basicData[0,6],thisVar])
        variablePoints.append(variablePoint)
    except Exception as e:
        print('Failed: '+ str(e))
        print(varsFile[-10:-4])
        pass
variablePoints=np.array(variablePoints)

# %% [markdown]
# ## Calculate HRy flattener

# %%
# transform HRy
absMag = closePoints[:,5].astype(np.float) + 2*np.log10(1/closePoints[:,3].astype(np.float))
BenchMark = np.array([closePoints[:,4].astype(np.float), absMag]).T
branches=[]
# Identify benchmark main seqence cluster with BGMM
branchCount = 4   # clusterCount
tol=0.0005
countStep = 5
CountTrials = 10
branchesModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                n_components=branchCount,
                covariance_type="full",
                n_init = CountTrials
                )).fit(BenchMark)    
branchShapes = branchesModel.predict(BenchMark)
# Collate branch points
for i, (weights) in enumerate(branchesModel.weights_):
    if not np.any(branchShapes == i) or weights<(0.01/branchCount):
        continue        
    branches.append(BenchMark[branchShapes == i, :])
## get Main sequence to fit polynomial
clusterSize=0
i=0
MSindex=0
for branch in branches:
    if len(branch)>clusterSize:
        clusterSize=len(branch)
        MSindex=i
    i=i+1
mainSequenceBenchmark=branches[MSindex]
MSFit4=np.poly1d(np.polyfit(mainSequenceBenchmark[:,0],mainSequenceBenchmark[:,1],4))
MSFit1=np.poly1d(np.polyfit(mainSequenceBenchmark[:,0],mainSequenceBenchmark[:,1],1))
# Transform all close points HR values
BenchMarktHRx=BenchMark[:,0]
BenchMarktHRy=BenchMark[:,1]-np.power(BenchMark[:,0],4)*MSFit4.c[0]-np.power(BenchMark[:,0],3)*MSFit4.c[1]-np.power(BenchMark[:,0],2)*MSFit4.c[2]-BenchMark[:,0]*MSFit4.c[3]-MSFit4.c[4]
linearBenchMarktHRy=BenchMark[:,1]-BenchMark[:,0]*MSFit1.c[0]-MSFit1.c[1]

# %% [markdown]
# ## breakdown point clusters

# %%
# Initiate output arrays
protoClusters = []
subClusters = []    #row = [ID, x, y, HRx, tHRy, rv]
clusters = []
# initiate input arrays
# X row = [ID, x, y, HRx, HRy, rv]
unassigned = []
# get protoClusters
X=np.concatenate([farPoints[:,[0,1,2,4,5,6]], midPoints[:,[0,1,2,4,5,6]]]).astype(np.float)
numberOfClusters = 1
NOCinc = 1
trials = 1
tol=0.001
WCP = 1
MPR = 1
minClusterSize=4
features=[1,2,5]
ProtoClustersModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                weight_concentration_prior=WCP,
                mean_precision_prior=MPR,
                n_components=numberOfClusters,
                covariance_type="full",
                n_init = trials
                )).fit(X[:,features])
while min(ProtoClustersModel.weights_)>(0.01/numberOfClusters):
    
    numberOfClusters=numberOfClusters+NOCinc
    
    ProtoClustersModel = (mixture.BayesianGaussianMixture(
                    weight_concentration_prior=WCP,
                    mean_precision_prior=MPR,
                    tol=tol,
                    n_components=numberOfClusters,
                    covariance_type="full",
                    n_init = trials
                    )).fit(X[:,features])
ProtoClustersModel = (mixture.BayesianGaussianMixture(
                tol=tol,
                weight_concentration_prior=WCP,
                mean_precision_prior=MPR,
                n_components=numberOfClusters-1,
                covariance_type="full",
                n_init = trials
                )).fit(X[:,features])
protoClusterShapes = ProtoClustersModel.predict(X[:,features])
for i, weights in enumerate(ProtoClustersModel.weights_):
    
    if not np.any(protoClusterShapes == i) or weights<(0.01/numberOfClusters) or len(X[protoClusterShapes == i, :])<minClusterSize:
        print('rejected: ', str(len(X[protoClusterShapes == i, :])))
        try:
            unassigned.append(X[protoClusterShapes == i, :].tolist()[0])
            continue
        except:
            continue
    protoClusters.append(X[protoClusterShapes == i, :])
totalPointsP = 0

# get subClusters
for protoCluster in protoClusters:
    # parameters
    tol=0.001
    numberOfSubClusterCount = 3   #initial clusterCount
    minSubclusterSize = 20
    trials = 5
    features=[1,2,5]
    subClustersModel = (mixture.BayesianGaussianMixture(
                        tol=tol,
                        n_components=numberOfSubClusterCount,
                        covariance_type="full",
                        )).fit(protoCluster[:,features])
    while min(subClustersModel.weights_)>(0.1/numberOfSubClusterCount):
        numberOfSubClusterCount = numberOfSubClusterCount + 1
        subClustersModel = (mixture.BayesianGaussianMixture(
                            n_init = trials,
                            tol=tol,
                            n_components=numberOfSubClusterCount,
                            covariance_type="full",
                            )).fit(protoCluster[:,features])
    subClustersModel = (mixture.BayesianGaussianMixture(
                        n_init = trials,
                        tol=tol,
                        n_components=numberOfSubClusterCount-1,
                        covariance_type="full",
                        )).fit(protoCluster[:,features])
    subClusterShapes = subClustersModel.predict(protoCluster[:,features])
# collate subclusters
    for i, (weights) in enumerate(subClustersModel.weights_):
        if not np.any(subClusterShapes == i) or len(protoCluster[subClusterShapes == i, :])<minSubclusterSize:
            try:
                test = protoCluster[subClusterShapes == i, :].tolist()[:][:]
                unassigned.extend(protoCluster[subClusterShapes == i, :].tolist()[:][:])
                # print('unassigned 1')
            except:
                # print('unassigned failed')
            continue
        temp=protoCluster[subClusterShapes == i, :]
        subClusters.append(np.array([temp[:,0],temp[:,1],temp[:,2],temp[:,3],temp[:,4], temp[:,5]]).T)
subClusters=np.array(subClusters)
# Out:
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1
# unassigned 1

# %% [markdown]
# ## Rebuild points clusters

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d, Delaunay
from scipy.interpolate import griddata
# Calculate prereq cluster data (boundary, Main sequence HRy, RV profile)
# 
        # tHRy = temp[:,4]-np.square(temp[:,3])*MSFit.c[0]-temp[:,3]*MSFit.c[1]-MSFit.c[2]

subClusterMS = []
boundaries = []
RVP = []
for subCluster in subClusters:
    Xms = np.array([subCluster[:,3], subCluster[:,4]-np.power(subCluster[:,3],4)*MSFit4.c[0]-np.power(subCluster[:,3],3)*MSFit4.c[1]-np.power(subCluster[:,3],2)*MSFit4.c[2]-subCluster[:,3]*MSFit4.c[3]-MSFit4.c[4]]).T
    ltHRy = np.array([subCluster[:,3],subCluster[:,4]-subCluster[:,3]*MSFit1.c[0]-MSFit1.c[1]]).T

    branches=[]
    # Identify benchmark main seqence cluster with BGMM
    branchCount = 3   # clusterCount
    countStep = 5
    CountTrials = 3
    branchesModel = (mixture.BayesianGaussianMixture(
                    n_components=branchCount,
                    covariance_type="full",
                    n_init = CountTrials
                    )).fit(ltHRy)    
    branchShapes = branchesModel.predict(ltHRy)
    # Collate branch points
    for i, (weights) in enumerate(branchesModel.weights_):
        if not np.any(branchShapes == i) or weights<(0.01/branchCount):
            continue        
        branches.append(Xms[branchShapes == i, :])
    ## get Main sequence to fit polynomial
    clusterSize=0
    i=0
    MSindex=0
    for branch in branches:
        if len(branch)>clusterSize:
            clusterSize=len(branch)
            MSindex=i
        i=i+1
    subClusterMS.append(branches[MSindex][branches[MSindex][:,0]>-0.6,:])
    
    
    boundary=subCluster[:,[1,2]]
    boundaries.append(Delaunay(boundary))   
    # get RVfit
    xi, yi = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))
    RVP.append(griddata(subCluster[:,[1,2]], subCluster[:,5], (xi,yi), method='cubic'))
    
boundaries = np.array(boundaries) 
xi, yi = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))   
clusters = subClusters
clusterMS = np.array(subClusterMS)
exists = np.ones(len(clusters)).astype(int)
oldExistSum=np.infty
while np.sum(exists)<oldExistSum:
    oldExistSum=np.sum(exists)
    exists = np.ones(len(clusters)).astype(int)
    for h, hostCluster in enumerate(clusters):
        # get cluster boundary
        if exists[h]==1:
            for i, otherCluster in enumerate(clusters):
                overlap = sum(abs(in_hull(otherCluster[:,[1,2]], boundaries[h])))
                difMeans = np.sqrt((np.mean(otherCluster[:,1])-np.mean(hostCluster[:,1]))**2 + (np.mean(otherCluster[:,2])-np.mean(hostCluster[:,2]))**2)
                maxRH = max(np.sqrt((hostCluster[:,1]-np.mean(hostCluster[:,1]))**2 + (hostCluster[:,2]-np.mean(hostCluster[:,2]))**2))
                maxRO = max(np.sqrt((otherCluster[:,1]-np.mean(otherCluster[:,1]))**2 + (otherCluster[:,2]-np.mean(otherCluster[:,2]))**2))
                maxR =maxRH + maxRO
                if (exists[i]==1):
                    print("Host: ", h, ', index: ', i, 'overlap: ', overlap)                                         # only use existing clusters
                    if (i != h
                    and (overlap>0                                        # overlap checker
                    or difMeans<maxR)
                       ):
                            tTest=sp.stats.ttest_ind(clusterMS[h][:,1], clusterMS[i][:,1], axis=0, equal_var=False)
                            print('        ',tTest)
                            if tTest[1]>0.05:
                                print('        ', h, ' match with ', i)

                                clusters[h] = np.append(clusters[h],clusters[i],axis=0)      # Update host
                                boundaries[h] = Delaunay(clusters[h][:,[1,2]])
                                clusterMS[h] =  np.append(clusterMS[h],clusterMS[i],axis=0) 
                                # RVP[h] = sp.griddata(clusters[:,[1,2]], clusters[:,5], (xi,yi), method='cubic')
                                exists[i] = 0
    clusters=clusters[exists == 1]
    boundaries = boundaries[exists == 1]    
    clusterMS = clusterMS[exists == 1]
# Out:
# Host:  0 , index:  0 overlap:  199
# Host:  0 , index:  1 overlap:  0
#          Ttest_indResult(statistic=28.17683040057718, pvalue=4.341133726773929e-64)
# Host:  0 , index:  2 overlap:  1
#          Ttest_indResult(statistic=-0.6822307712200696, pvalue=0.5058963413769026)
#          0  match with  2
# Host:  0 , index:  3 overlap:  0
#          Ttest_indResult(statistic=-1.0754542847653197, pvalue=0.2835201850528249)
#          0  match with  3
# Host:  0 , index:  4 overlap:  8
#          Ttest_indResult(statistic=0.37682667952236537, pvalue=0.7087462140336552)
#          0  match with  4
# Host:  0 , index:  5 overlap:  0
# Host:  0 , index:  6 overlap:  0
# Host:  0 , index:  7 overlap:  0
# Host:  0 , index:  8 overlap:  0
# Host:  0 , index:  9 overlap:  0
# Host:  0 , index:  10 overlap:  0
# Host:  0 , index:  11 overlap:  0
# Host:  0 , index:  12 overlap:  0
# Host:  0 , index:  13 overlap:  0
# Host:  0 , index:  14 overlap:  0
# Host:  0 , index:  15 overlap:  0
# Host:  0 , index:  16 overlap:  0
# Host:  0 , index:  17 overlap:  0
# Host:  0 , index:  18 overlap:  0
# Host:  0 , index:  19 overlap:  0
# Host:  0 , index:  20 overlap:  0
# Host:  0 , index:  21 overlap:  0
# Host:  0 , index:  22 overlap:  0
# Host:  0 , index:  23 overlap:  0
# Host:  0 , index:  24 overlap:  0
# Host:  0 , index:  25 overlap:  0
# Host:  0 , index:  26 overlap:  0
# Host:  0 , index:  27 overlap:  0
# Host:  0 , index:  28 overlap:  0
# Host:  0 , index:  29 overlap:  0
# Host:  0 , index:  30 overlap:  0
# Host:  0 , index:  31 overlap:  0
# Host:  0 , index:  32 overlap:  0
# Host:  0 , index:  33 overlap:  0
# Host:  0 , index:  34 overlap:  0
# Host:  0 , index:  35 overlap:  0
# Host:  0 , index:  36 overlap:  0
# Host:  0 , index:  37 overlap:  0
# Host:  0 , index:  38 overlap:  0
# Host:  0 , index:  39 overlap:  0
# Host:  0 , index:  40 overlap:  0
# Host:  0 , index:  41 overlap:  0
# Host:  0 , index:  42 overlap:  0
# Host:  0 , index:  43 overlap:  0
# Host:  0 , index:  44 overlap:  0
# Host:  0 , index:  45 overlap:  0
# Host:  0 , index:  46 overlap:  0
# Host:  0 , index:  47 overlap:  0
# Host:  0 , index:  48 overlap:  0
# Host:  0 , index:  49 overlap:  0
# Host:  0 , index:  50 overlap:  0
# Host:  1 , index:  0 overlap:  2
#          Ttest_indResult(statistic=-31.920019383456477, pvalue=2.526001869425467e-60)
# Host:  1 , index:  1 overlap:  124
# Host:  1 , index:  5 overlap:  0
# Host:  1 , index:  6 overlap:  0
# Host:  1 , index:  7 overlap:  0
# Host:  1 , index:  8 overlap:  0
# Host:  1 , index:  9 overlap:  0
# Host:  1 , index:  10 overlap:  0
# Host:  1 , index:  11 overlap:  0
# Host:  1 , index:  12 overlap:  0
# Host:  1 , index:  13 overlap:  0
# Host:  1 , index:  14 overlap:  0
# Host:  1 , index:  15 overlap:  0
# Host:  1 , index:  16 overlap:  0
# Host:  1 , index:  17 overlap:  0
# Host:  1 , index:  18 overlap:  0
# Host:  1 , index:  19 overlap:  0
# Host:  1 , index:  20 overlap:  0
# Host:  1 , index:  21 overlap:  0
# Host:  1 , index:  22 overlap:  0
# Host:  1 , index:  23 overlap:  0
# Host:  1 , index:  24 overlap:  0
# Host:  1 , index:  25 overlap:  0
# Host:  1 , index:  26 overlap:  0
# Host:  1 , index:  27 overlap:  0
# Host:  1 , index:  28 overlap:  0
# Host:  1 , index:  29 overlap:  0
# Host:  1 , index:  30 overlap:  0
# Host:  1 , index:  31 overlap:  0
# Host:  1 , index:  32 overlap:  0
# Host:  1 , index:  33 overlap:  0
# Host:  1 , index:  34 overlap:  0
# Host:  1 , index:  35 overlap:  0
# Host:  1 , index:  36 overlap:  0
# Host:  1 , index:  37 overlap:  0
# Host:  1 , index:  38 overlap:  0
# Host:  1 , index:  39 overlap:  0
# Host:  1 , index:  40 overlap:  0
# Host:  1 , index:  41 overlap:  0
# Host:  1 , index:  42 overlap:  0
# Host:  1 , index:  43 overlap:  0
# Host:  1 , index:  44 overlap:  0
# Host:  1 , index:  45 overlap:  0
# Host:  1 , index:  46 overlap:  0
# Host:  1 , index:  47 overlap:  0
# Host:  1 , index:  48 overlap:  0
# Host:  1 , index:  49 overlap:  0
# Host:  1 , index:  50 overlap:  0
# Host:  5 , index:  0 overlap:  0
# Host:  5 , index:  1 overlap:  0
# Host:  5 , index:  5 overlap:  17
# Host:  5 , index:  6 overlap:  0
#          Ttest_indResult(statistic=0.8733736004666105, pvalue=0.39936511417214926)
#          5  match with  6
# Host:  5 , index:  7 overlap:  2
#          Ttest_indResult(statistic=1.93589946901215, pvalue=0.05827261948094902)
#          5  match with  7
# Host:  5 , index:  8 overlap:  27
#          Ttest_indResult(statistic=-2.0394217316575336, pvalue=0.04942406138174066)
# Host:  5 , index:  9 overlap:  0
#          Ttest_indResult(statistic=-1.9725486315656182, pvalue=0.06061446959171861)
#          5  match with  9
# Host:  5 , index:  10 overlap:  0
# Host:  5 , index:  11 overlap:  0
# Host:  5 , index:  12 overlap:  0
# Host:  5 , index:  13 overlap:  0
# Host:  5 , index:  14 overlap:  0
# Host:  5 , index:  15 overlap:  0
# Host:  5 , index:  16 overlap:  0
# Host:  5 , index:  17 overlap:  0
# Host:  5 , index:  18 overlap:  0
# Host:  5 , index:  19 overlap:  0
# Host:  5 , index:  20 overlap:  0
# Host:  5 , index:  21 overlap:  0
# Host:  5 , index:  22 overlap:  0
# Host:  5 , index:  23 overlap:  0
# Host:  5 , index:  24 overlap:  0
# Host:  5 , index:  25 overlap:  0
# Host:  5 , index:  26 overlap:  0
# Host:  5 , index:  27 overlap:  0
# Host:  5 , index:  28 overlap:  0
# Host:  5 , index:  29 overlap:  0
# Host:  5 , index:  30 overlap:  0
# Host:  5 , index:  31 overlap:  0
# Host:  5 , index:  32 overlap:  0
# Host:  5 , index:  33 overlap:  0
# Host:  5 , index:  34 overlap:  0
# Host:  5 , index:  35 overlap:  0
# Host:  5 , index:  36 overlap:  0
# Host:  5 , index:  37 overlap:  0
# Host:  5 , index:  38 overlap:  0
# Host:  5 , index:  39 overlap:  0
# Host:  5 , index:  40 overlap:  0
# Host:  5 , index:  41 overlap:  0
# Host:  5 , index:  42 overlap:  0
# Host:  5 , index:  43 overlap:  0
# Host:  5 , index:  44 overlap:  0
# Host:  5 , index:  45 overlap:  0
# Host:  5 , index:  46 overlap:  0
# Host:  5 , index:  47 overlap:  0
# Host:  5 , index:  48 overlap:  0
# Host:  5 , index:  49 overlap:  0
# Host:  5 , index:  50 overlap:  0
# Host:  8 , index:  0 overlap:  0
# Host:  8 , index:  1 overlap:  0
# Host:  8 , index:  5 overlap:  0
#          Ttest_indResult(statistic=1.8801937056965805, pvalue=0.06935739776542088)
#          8  match with  5
# Host:  8 , index:  8 overlap:  269
# Host:  8 , index:  10 overlap:  0
# Host:  8 , index:  11 overlap:  0
# Host:  8 , index:  12 overlap:  0
# Host:  8 , index:  13 overlap:  0
# Host:  8 , index:  14 overlap:  0
# Host:  8 , index:  15 overlap:  0
# Host:  8 , index:  16 overlap:  0
# Host:  8 , index:  17 overlap:  0
# Host:  8 , index:  18 overlap:  0
# Host:  8 , index:  19 overlap:  0
# Host:  8 , index:  20 overlap:  0
# Host:  8 , index:  21 overlap:  0
# Host:  8 , index:  22 overlap:  0
# Host:  8 , index:  23 overlap:  0
# Host:  8 , index:  24 overlap:  0
# Host:  8 , index:  25 overlap:  0
# Host:  8 , index:  26 overlap:  0
# Host:  8 , index:  27 overlap:  0
# Host:  8 , index:  28 overlap:  0
# Host:  8 , index:  29 overlap:  0
# Host:  8 , index:  30 overlap:  0
# Host:  8 , index:  31 overlap:  0
# Host:  8 , index:  32 overlap:  0
# Host:  8 , index:  33 overlap:  0
# Host:  8 , index:  34 overlap:  0
# Host:  8 , index:  35 overlap:  0
# Host:  8 , index:  36 overlap:  0
# Host:  8 , index:  37 overlap:  0
# Host:  8 , index:  38 overlap:  0
# Host:  8 , index:  39 overlap:  0
# Host:  8 , index:  40 overlap:  0
# Host:  8 , index:  41 overlap:  0
# Host:  8 , index:  42 overlap:  0
# Host:  8 , index:  43 overlap:  0
# Host:  8 , index:  44 overlap:  0
# Host:  8 , index:  45 overlap:  0
# Host:  8 , index:  46 overlap:  0
# Host:  8 , index:  47 overlap:  0
# Host:  8 , index:  48 overlap:  0
# Host:  8 , index:  49 overlap:  0
# Host:  8 , index:  50 overlap:  0
# Host:  10 , index:  0 overlap:  0
# Host:  10 , index:  1 overlap:  0
# Host:  10 , index:  8 overlap:  0
# Host:  10 , index:  10 overlap:  104
# Host:  10 , index:  11 overlap:  0
#          Ttest_indResult(statistic=0.9215860113235154, pvalue=0.360766653677162)
#          10  match with  11
# Host:  10 , index:  12 overlap:  1
#          Ttest_indResult(statistic=2.567646430182508, pvalue=0.015417248377175919)
# Host:  10 , index:  13 overlap:  1
#          Ttest_indResult(statistic=-0.09410115335691532, pvalue=0.9255452966725208)
#          10  match with  13
# Host:  10 , index:  14 overlap:  0
# Host:  10 , index:  15 overlap:  0
# Host:  10 , index:  16 overlap:  0
# Host:  10 , index:  17 overlap:  0
# Host:  10 , index:  18 overlap:  0
# Host:  10 , index:  19 overlap:  0
# Host:  10 , index:  20 overlap:  0
# Host:  10 , index:  21 overlap:  0
# Host:  10 , index:  22 overlap:  0
# Host:  10 , index:  23 overlap:  0
# Host:  10 , index:  24 overlap:  0
# Host:  10 , index:  25 overlap:  0
# Host:  10 , index:  26 overlap:  0
# Host:  10 , index:  27 overlap:  0
# Host:  10 , index:  28 overlap:  0
# Host:  10 , index:  29 overlap:  0
# Host:  10 , index:  30 overlap:  0
#          Ttest_indResult(statistic=-29.501828223760278, pvalue=1.1033992006702172e-24)
# Host:  10 , index:  31 overlap:  0
# Host:  10 , index:  32 overlap:  0
# Host:  10 , index:  33 overlap:  0
# Host:  10 , index:  34 overlap:  0
# Host:  10 , index:  35 overlap:  0
# Host:  10 , index:  36 overlap:  0
# Host:  10 , index:  37 overlap:  0
# Host:  10 , index:  38 overlap:  0
# Host:  10 , index:  39 overlap:  0
# Host:  10 , index:  40 overlap:  0
# Host:  10 , index:  41 overlap:  0
# Host:  10 , index:  42 overlap:  0
# Host:  10 , index:  43 overlap:  0
# Host:  10 , index:  44 overlap:  0
# Host:  10 , index:  45 overlap:  0
# Host:  10 , index:  46 overlap:  0
# Host:  10 , index:  47 overlap:  0
# Host:  10 , index:  48 overlap:  0
# Host:  10 , index:  49 overlap:  0
# Host:  10 , index:  50 overlap:  0
# Host:  12 , index:  0 overlap:  0
# Host:  12 , index:  1 overlap:  0
# Host:  12 , index:  8 overlap:  0
# Host:  12 , index:  10 overlap:  121
#          Ttest_indResult(statistic=-2.6435630704319277, pvalue=0.01335080548354596)
# Host:  12 , index:  12 overlap:  26
# Host:  12 , index:  14 overlap:  0
# Host:  12 , index:  15 overlap:  0
# Host:  12 , index:  16 overlap:  0
# Host:  12 , index:  17 overlap:  0
# Host:  12 , index:  18 overlap:  0
# Host:  12 , index:  19 overlap:  0
# Host:  12 , index:  20 overlap:  0
# Host:  12 , index:  21 overlap:  0
# Host:  12 , index:  22 overlap:  0
# Host:  12 , index:  23 overlap:  0
# Host:  12 , index:  24 overlap:  0
# Host:  12 , index:  25 overlap:  0
# Host:  12 , index:  26 overlap:  0
# Host:  12 , index:  27 overlap:  0
# Host:  12 , index:  28 overlap:  0
# Host:  12 , index:  29 overlap:  0
# Host:  12 , index:  30 overlap:  0
#          Ttest_indResult(statistic=-28.155569732800874, pvalue=5.814096611503296e-29)
# Host:  12 , index:  31 overlap:  0
# Host:  12 , index:  32 overlap:  0
# Host:  12 , index:  33 overlap:  0
# Host:  12 , index:  34 overlap:  0
# Host:  12 , index:  35 overlap:  0
# Host:  12 , index:  36 overlap:  0
# Host:  12 , index:  37 overlap:  0
# Host:  12 , index:  38 overlap:  0
# Host:  12 , index:  39 overlap:  0
# Host:  12 , index:  40 overlap:  0
# Host:  12 , index:  41 overlap:  0
# Host:  12 , index:  42 overlap:  0
# Host:  12 , index:  43 overlap:  0
# Host:  12 , index:  44 overlap:  0
# Host:  12 , index:  45 overlap:  0
# Host:  12 , index:  46 overlap:  0
# Host:  12 , index:  47 overlap:  0
# Host:  12 , index:  48 overlap:  0
# Host:  12 , index:  49 overlap:  0
# Host:  12 , index:  50 overlap:  0
# Host:  14 , index:  0 overlap:  0
# Host:  14 , index:  1 overlap:  0
# Host:  14 , index:  8 overlap:  0
# Host:  14 , index:  10 overlap:  0
# Host:  14 , index:  12 overlap:  0
# Host:  14 , index:  14 overlap:  86
# Host:  14 , index:  15 overlap:  0
# Host:  14 , index:  16 overlap:  0
# Host:  14 , index:  17 overlap:  0
#          Ttest_indResult(statistic=0.3538915874291972, pvalue=0.7257467161890723)
#          14  match with  17
# Host:  14 , index:  18 overlap:  4
#          Ttest_indResult(statistic=0.6705733801837992, pvalue=0.5083614749061774)
#          14  match with  18
# Host:  14 , index:  19 overlap:  72
#          Ttest_indResult(statistic=0.712305515035805, pvalue=0.4776015655547817)
#          14  match with  19
# Host:  14 , index:  20 overlap:  8
#          Ttest_indResult(statistic=-1.0443002118372504, pvalue=0.31010216391404977)
#          14  match with  20
# Host:  14 , index:  21 overlap:  0
# Host:  14 , index:  22 overlap:  0
# Host:  14 , index:  23 overlap:  0
# Host:  14 , index:  24 overlap:  0
# Host:  14 , index:  25 overlap:  0
# Host:  14 , index:  26 overlap:  0
# Host:  14 , index:  27 overlap:  0
# Host:  14 , index:  28 overlap:  0
# Host:  14 , index:  29 overlap:  0
# Host:  14 , index:  30 overlap:  0
# Host:  14 , index:  31 overlap:  0
# Host:  14 , index:  32 overlap:  0
# Host:  14 , index:  33 overlap:  0
# Host:  14 , index:  34 overlap:  0
# Host:  14 , index:  35 overlap:  0
# Host:  14 , index:  36 overlap:  0
# Host:  14 , index:  37 overlap:  0
# Host:  14 , index:  38 overlap:  0
# Host:  14 , index:  39 overlap:  0
# Host:  14 , index:  40 overlap:  0
# Host:  14 , index:  41 overlap:  0
# Host:  14 , index:  42 overlap:  0
# Host:  14 , index:  43 overlap:  0
# Host:  14 , index:  44 overlap:  0
# Host:  14 , index:  45 overlap:  0
# Host:  14 , index:  46 overlap:  67
#          Ttest_indResult(statistic=-2.4194538985403056, pvalue=0.016710658947481027)
# Host:  14 , index:  47 overlap:  32
#          Ttest_indResult(statistic=-0.09226569921257502, pvalue=0.927101147148014)
#          14  match with  47
# Host:  14 , index:  48 overlap:  4
#          Ttest_indResult(statistic=-0.06620224392907782, pvalue=0.9478013924668173)
#          14  match with  48
# Host:  14 , index:  49 overlap:  19
#          Ttest_indResult(statistic=-0.42926060004195715, pvalue=0.6735793841489275)
#          14  match with  49
# Host:  14 , index:  50 overlap:  31
#          Ttest_indResult(statistic=0.5198236916036922, pvalue=0.6077879434523477)
#          14  match with  50
# Host:  15 , index:  0 overlap:  0
# Host:  15 , index:  1 overlap:  0
# Host:  15 , index:  8 overlap:  0
# Host:  15 , index:  10 overlap:  0
# Host:  15 , index:  12 overlap:  0
# Host:  15 , index:  14 overlap:  2
#          Ttest_indResult(statistic=0.9438535167954557, pvalue=0.346052293303165)
#          15  match with  14
# Host:  15 , index:  15 overlap:  503
# Host:  15 , index:  16 overlap:  187
#          Ttest_indResult(statistic=4.35975215786648, pvalue=2.000633527078794e-05)
# Host:  15 , index:  21 overlap:  0
# Host:  15 , index:  22 overlap:  0
# Host:  15 , index:  23 overlap:  0
# Host:  15 , index:  24 overlap:  0
# Host:  15 , index:  25 overlap:  0
# Host:  15 , index:  26 overlap:  0
# Host:  15 , index:  27 overlap:  0
# Host:  15 , index:  28 overlap:  0
# Host:  15 , index:  29 overlap:  0
# Host:  15 , index:  30 overlap:  0
# Host:  15 , index:  31 overlap:  0
# Host:  15 , index:  32 overlap:  0
# Host:  15 , index:  33 overlap:  0
# Host:  15 , index:  34 overlap:  0
# Host:  15 , index:  35 overlap:  0
# Host:  15 , index:  36 overlap:  0
# Host:  15 , index:  37 overlap:  0
# Host:  15 , index:  38 overlap:  0
# Host:  15 , index:  39 overlap:  0
# Host:  15 , index:  40 overlap:  0
# Host:  15 , index:  41 overlap:  0
# Host:  15 , index:  42 overlap:  0
# Host:  15 , index:  43 overlap:  0
# Host:  15 , index:  44 overlap:  0
# Host:  15 , index:  45 overlap:  0
# Host:  15 , index:  46 overlap:  108
#          Ttest_indResult(statistic=-2.4658993077651554, pvalue=0.015229756595875513)
# Host:  16 , index:  0 overlap:  0
# Host:  16 , index:  1 overlap:  0
# Host:  16 , index:  8 overlap:  0
# Host:  16 , index:  10 overlap:  0
# Host:  16 , index:  12 overlap:  0
# Host:  16 , index:  15 overlap:  1
#          Ttest_indResult(statistic=-4.35975215786648, pvalue=2.000633527078794e-05)
# Host:  16 , index:  16 overlap:  187
# Host:  16 , index:  21 overlap:  0
# Host:  16 , index:  22 overlap:  0
# Host:  16 , index:  23 overlap:  0
# Host:  16 , index:  24 overlap:  0
# Host:  16 , index:  25 overlap:  0
# Host:  16 , index:  26 overlap:  0
# Host:  16 , index:  27 overlap:  0
# Host:  16 , index:  28 overlap:  0
# Host:  16 , index:  29 overlap:  0
# Host:  16 , index:  30 overlap:  0
# Host:  16 , index:  31 overlap:  0
# Host:  16 , index:  32 overlap:  0
# Host:  16 , index:  33 overlap:  0
# Host:  16 , index:  34 overlap:  0
# Host:  16 , index:  35 overlap:  0
# Host:  16 , index:  36 overlap:  0
# Host:  16 , index:  37 overlap:  0
# Host:  16 , index:  38 overlap:  0
# Host:  16 , index:  39 overlap:  0
# Host:  16 , index:  40 overlap:  0
# Host:  16 , index:  41 overlap:  0
# Host:  16 , index:  42 overlap:  0
# Host:  16 , index:  43 overlap:  0
# Host:  16 , index:  44 overlap:  0
# Host:  16 , index:  45 overlap:  0
# Host:  16 , index:  46 overlap:  0
# Host:  21 , index:  0 overlap:  0
# Host:  21 , index:  1 overlap:  0
# Host:  21 , index:  8 overlap:  0
# Host:  21 , index:  10 overlap:  0
# Host:  21 , index:  12 overlap:  0
# Host:  21 , index:  15 overlap:  0
# Host:  21 , index:  16 overlap:  0
# Host:  21 , index:  21 overlap:  225
# Host:  21 , index:  22 overlap:  0
#          Ttest_indResult(statistic=-0.9057291693558378, pvalue=0.3736790349563661)
#          21  match with  22
# Host:  21 , index:  23 overlap:  0
#          Ttest_indResult(statistic=0.7852159822977921, pvalue=0.4392628764800688)
#          21  match with  23
# Host:  21 , index:  24 overlap:  0
# Host:  21 , index:  25 overlap:  0
# Host:  21 , index:  26 overlap:  0
# Host:  21 , index:  27 overlap:  0
# Host:  21 , index:  28 overlap:  0
# Host:  21 , index:  29 overlap:  0
# Host:  21 , index:  30 overlap:  0
# Host:  21 , index:  31 overlap:  0
# Host:  21 , index:  32 overlap:  0
# Host:  21 , index:  33 overlap:  0
# Host:  21 , index:  34 overlap:  0
# Host:  21 , index:  35 overlap:  0
# Host:  21 , index:  36 overlap:  0
# Host:  21 , index:  37 overlap:  0
# Host:  21 , index:  38 overlap:  0
# Host:  21 , index:  39 overlap:  0
# Host:  21 , index:  40 overlap:  0
# Host:  21 , index:  41 overlap:  0
# Host:  21 , index:  42 overlap:  0
# Host:  21 , index:  43 overlap:  0
# Host:  21 , index:  44 overlap:  0
# Host:  21 , index:  45 overlap:  0
# Host:  21 , index:  46 overlap:  0
# Host:  24 , index:  0 overlap:  0
# Host:  24 , index:  1 overlap:  0
# Host:  24 , index:  8 overlap:  0
# Host:  24 , index:  10 overlap:  0
# Host:  24 , index:  12 overlap:  0
# Host:  24 , index:  15 overlap:  0
# Host:  24 , index:  16 overlap:  0
# Host:  24 , index:  21 overlap:  0
# Host:  24 , index:  24 overlap:  132
# Host:  24 , index:  25 overlap:  0
# Host:  24 , index:  26 overlap:  0
#          Ttest_indResult(statistic=-3.2749546208252522, pvalue=0.003962083819260574)
# Host:  24 , index:  27 overlap:  0
#          Ttest_indResult(statistic=-3.844596846408282, pvalue=0.0017122015621329454)
# Host:  24 , index:  28 overlap:  0
# Host:  24 , index:  29 overlap:  0
# Host:  24 , index:  30 overlap:  0
# Host:  24 , index:  31 overlap:  0
# Host:  24 , index:  32 overlap:  0
# Host:  24 , index:  33 overlap:  0
# Host:  24 , index:  34 overlap:  0
# Host:  24 , index:  35 overlap:  0
# Host:  24 , index:  36 overlap:  0
# Host:  24 , index:  37 overlap:  0
# Host:  24 , index:  38 overlap:  0
# Host:  24 , index:  39 overlap:  0
# Host:  24 , index:  40 overlap:  0
# Host:  24 , index:  41 overlap:  0
# Host:  24 , index:  42 overlap:  0
# Host:  24 , index:  43 overlap:  0
# Host:  24 , index:  44 overlap:  0
# Host:  24 , index:  45 overlap:  0
# Host:  24 , index:  46 overlap:  0
# Host:  25 , index:  0 overlap:  0
# Host:  25 , index:  1 overlap:  0
# Host:  25 , index:  8 overlap:  0
# Host:  25 , index:  10 overlap:  0
# Host:  25 , index:  12 overlap:  0
# Host:  25 , index:  15 overlap:  0
# Host:  25 , index:  16 overlap:  0
# Host:  25 , index:  21 overlap:  0
# Host:  25 , index:  24 overlap:  0
# Host:  25 , index:  25 overlap:  127
# Host:  25 , index:  26 overlap:  0
#          Ttest_indResult(statistic=0.3560846342711449, pvalue=0.7241945558789551)
#          25  match with  26
# Host:  25 , index:  27 overlap:  4
#          Ttest_indResult(statistic=-1.429846102433612, pvalue=0.17083355798442612)
#          25  match with  27
# Host:  25 , index:  28 overlap:  0
# Host:  25 , index:  29 overlap:  0
# Host:  25 , index:  30 overlap:  0
# Host:  25 , index:  31 overlap:  0
# Host:  25 , index:  32 overlap:  0
# Host:  25 , index:  33 overlap:  0
# Host:  25 , index:  34 overlap:  0
# Host:  25 , index:  35 overlap:  0
# Host:  25 , index:  36 overlap:  0
# Host:  25 , index:  37 overlap:  0
# Host:  25 , index:  38 overlap:  0
# Host:  25 , index:  39 overlap:  0
# Host:  25 , index:  40 overlap:  0
# Host:  25 , index:  41 overlap:  0
# Host:  25 , index:  42 overlap:  0
# Host:  25 , index:  43 overlap:  0
# Host:  25 , index:  44 overlap:  0
# Host:  25 , index:  45 overlap:  0
# Host:  25 , index:  46 overlap:  0
# Host:  28 , index:  0 overlap:  0
# Host:  28 , index:  1 overlap:  0
# Host:  28 , index:  8 overlap:  0
# Host:  28 , index:  10 overlap:  0
# Host:  28 , index:  12 overlap:  0
# Host:  28 , index:  15 overlap:  0
# Host:  28 , index:  16 overlap:  0
# Host:  28 , index:  21 overlap:  0
# Host:  28 , index:  24 overlap:  0
# Host:  28 , index:  25 overlap:  0
# Host:  28 , index:  28 overlap:  105
# Host:  28 , index:  29 overlap:  0
#          Ttest_indResult(statistic=0.0076861604404339584, pvalue=0.9939072317938602)
#          28  match with  29
# Host:  28 , index:  30 overlap:  1
#          Ttest_indResult(statistic=1.7499157322085999, pvalue=0.08753238794084799)
#          28  match with  30
# Host:  28 , index:  31 overlap:  0
# Host:  28 , index:  32 overlap:  0
# Host:  28 , index:  33 overlap:  0
# Host:  28 , index:  34 overlap:  0
# Host:  28 , index:  35 overlap:  0
# Host:  28 , index:  36 overlap:  0
# Host:  28 , index:  37 overlap:  0
# Host:  28 , index:  38 overlap:  0
# Host:  28 , index:  39 overlap:  0
# Host:  28 , index:  40 overlap:  0
# Host:  28 , index:  41 overlap:  0
# Host:  28 , index:  42 overlap:  0
# Host:  28 , index:  43 overlap:  0
# Host:  28 , index:  44 overlap:  0
# Host:  28 , index:  45 overlap:  0
# Host:  28 , index:  46 overlap:  0
# Host:  31 , index:  0 overlap:  0
# Host:  31 , index:  1 overlap:  0
# Host:  31 , index:  8 overlap:  0
# Host:  31 , index:  10 overlap:  0
# Host:  31 , index:  12 overlap:  0
# Host:  31 , index:  15 overlap:  0
# Host:  31 , index:  16 overlap:  0
# Host:  31 , index:  21 overlap:  0
# Host:  31 , index:  24 overlap:  0
# Host:  31 , index:  25 overlap:  0
# Host:  31 , index:  28 overlap:  0
# Host:  31 , index:  31 overlap:  107
# Host:  31 , index:  32 overlap:  0
# Host:  31 , index:  33 overlap:  0
# Host:  31 , index:  34 overlap:  0
# Host:  31 , index:  35 overlap:  0
# Host:  31 , index:  36 overlap:  0
# Host:  31 , index:  37 overlap:  0
# Host:  31 , index:  38 overlap:  0
# Host:  31 , index:  39 overlap:  0
# Host:  31 , index:  40 overlap:  0
# Host:  31 , index:  41 overlap:  0
# Host:  31 , index:  42 overlap:  0
# Host:  31 , index:  43 overlap:  0
# Host:  31 , index:  44 overlap:  0
# Host:  31 , index:  45 overlap:  0
# Host:  31 , index:  46 overlap:  0
# Host:  32 , index:  0 overlap:  0
# Host:  32 , index:  1 overlap:  0
# Host:  32 , index:  8 overlap:  0
# Host:  32 , index:  10 overlap:  0
# Host:  32 , index:  12 overlap:  0
# Host:  32 , index:  15 overlap:  0
# Host:  32 , index:  16 overlap:  0
# Host:  32 , index:  21 overlap:  0
# Host:  32 , index:  24 overlap:  0
# Host:  32 , index:  25 overlap:  0
# Host:  32 , index:  28 overlap:  0
# Host:  32 , index:  31 overlap:  0
# Host:  32 , index:  32 overlap:  55
# Host:  32 , index:  33 overlap:  0
#          Ttest_indResult(statistic=3.0294840218698935, pvalue=0.007752967730058061)
# Host:  32 , index:  34 overlap:  0
# Host:  32 , index:  35 overlap:  0
# Host:  32 , index:  36 overlap:  0
# Host:  32 , index:  37 overlap:  0
# Host:  32 , index:  38 overlap:  0
# Host:  32 , index:  39 overlap:  0
# Host:  32 , index:  40 overlap:  0
# Host:  32 , index:  41 overlap:  0
# Host:  32 , index:  42 overlap:  0
# Host:  32 , index:  43 overlap:  0
# Host:  32 , index:  44 overlap:  0
# Host:  32 , index:  45 overlap:  0
# Host:  32 , index:  46 overlap:  0
# Host:  33 , index:  0 overlap:  0
# Host:  33 , index:  1 overlap:  0
# Host:  33 , index:  8 overlap:  0
# Host:  33 , index:  10 overlap:  0
# Host:  33 , index:  12 overlap:  0
# Host:  33 , index:  15 overlap:  0
# Host:  33 , index:  16 overlap:  0
# Host:  33 , index:  21 overlap:  0
# Host:  33 , index:  24 overlap:  0
# Host:  33 , index:  25 overlap:  0
# Host:  33 , index:  28 overlap:  0
# Host:  33 , index:  31 overlap:  0
# Host:  33 , index:  32 overlap:  2
#          Ttest_indResult(statistic=-3.0294840218698935, pvalue=0.007752967730058061)
# Host:  33 , index:  33 overlap:  24
# Host:  33 , index:  34 overlap:  0
# Host:  33 , index:  35 overlap:  0
# Host:  33 , index:  36 overlap:  0
# Host:  33 , index:  37 overlap:  0
# Host:  33 , index:  38 overlap:  0
# Host:  33 , index:  39 overlap:  0
# Host:  33 , index:  40 overlap:  0
# Host:  33 , index:  41 overlap:  0
# Host:  33 , index:  42 overlap:  0
# Host:  33 , index:  43 overlap:  0
# Host:  33 , index:  44 overlap:  0
# Host:  33 , index:  45 overlap:  0
# Host:  33 , index:  46 overlap:  0
# Host:  34 , index:  0 overlap:  0
# Host:  34 , index:  1 overlap:  0
# Host:  34 , index:  8 overlap:  0
# Host:  34 , index:  10 overlap:  0
# Host:  34 , index:  12 overlap:  0
# Host:  34 , index:  15 overlap:  0
# Host:  34 , index:  16 overlap:  0
# Host:  34 , index:  21 overlap:  0
# Host:  34 , index:  24 overlap:  0
# Host:  34 , index:  25 overlap:  0
# Host:  34 , index:  28 overlap:  0
# Host:  34 , index:  31 overlap:  0
# Host:  34 , index:  32 overlap:  0
# Host:  34 , index:  33 overlap:  0
# Host:  34 , index:  34 overlap:  25
# Host:  34 , index:  35 overlap:  0
#          Ttest_indResult(statistic=2.740848981424568, pvalue=0.014051016274679168)
# Host:  34 , index:  36 overlap:  31
#          Ttest_indResult(statistic=-0.9122937512989467, pvalue=0.36736052905227534)
#          34  match with  36
# Host:  34 , index:  37 overlap:  0
# Host:  34 , index:  38 overlap:  0
# Host:  34 , index:  39 overlap:  0
# Host:  34 , index:  40 overlap:  0
# Host:  34 , index:  41 overlap:  0
# Host:  34 , index:  42 overlap:  0
# Host:  34 , index:  43 overlap:  0
# Host:  34 , index:  44 overlap:  0
# Host:  34 , index:  45 overlap:  0
# Host:  34 , index:  46 overlap:  0
# Host:  35 , index:  0 overlap:  0
# Host:  35 , index:  1 overlap:  0
# Host:  35 , index:  8 overlap:  0
# Host:  35 , index:  10 overlap:  0
# Host:  35 , index:  12 overlap:  0
# Host:  35 , index:  15 overlap:  0
# Host:  35 , index:  16 overlap:  0
# Host:  35 , index:  21 overlap:  0
# Host:  35 , index:  24 overlap:  0
# Host:  35 , index:  25 overlap:  0
# Host:  35 , index:  28 overlap:  0
# Host:  35 , index:  31 overlap:  0
# Host:  35 , index:  32 overlap:  0
# Host:  35 , index:  33 overlap:  0
# Host:  35 , index:  34 overlap:  1
#          Ttest_indResult(statistic=-3.6847935870857063, pvalue=0.003455023928413923)
# Host:  35 , index:  35 overlap:  17
# Host:  35 , index:  37 overlap:  0
# Host:  35 , index:  38 overlap:  0
# Host:  35 , index:  39 overlap:  0
# Host:  35 , index:  40 overlap:  0
# Host:  35 , index:  41 overlap:  0
# Host:  35 , index:  42 overlap:  0
# Host:  35 , index:  43 overlap:  0
# Host:  35 , index:  44 overlap:  0
# Host:  35 , index:  45 overlap:  0
# Host:  35 , index:  46 overlap:  0
# Host:  37 , index:  0 overlap:  0
# Host:  37 , index:  1 overlap:  0
# Host:  37 , index:  8 overlap:  0
# Host:  37 , index:  10 overlap:  0
# Host:  37 , index:  12 overlap:  0
# Host:  37 , index:  15 overlap:  0
# Host:  37 , index:  16 overlap:  0
# Host:  37 , index:  21 overlap:  0
# Host:  37 , index:  24 overlap:  0
# Host:  37 , index:  25 overlap:  0
# Host:  37 , index:  28 overlap:  0
#          Ttest_indResult(statistic=-47.03793126608213, pvalue=7.638248681678056e-71)
# Host:  37 , index:  31 overlap:  0
# Host:  37 , index:  32 overlap:  0
# Host:  37 , index:  33 overlap:  0
# Host:  37 , index:  34 overlap:  0
# Host:  37 , index:  35 overlap:  0
# Host:  37 , index:  37 overlap:  86
# Host:  37 , index:  38 overlap:  0
# Host:  37 , index:  39 overlap:  0
# Host:  37 , index:  40 overlap:  0
# Host:  37 , index:  41 overlap:  0
# Host:  37 , index:  42 overlap:  0
# Host:  37 , index:  43 overlap:  0
# Host:  37 , index:  44 overlap:  0
# Host:  37 , index:  45 overlap:  0
# Host:  37 , index:  46 overlap:  0
# Host:  38 , index:  0 overlap:  0
# Host:  38 , index:  1 overlap:  0
# Host:  38 , index:  8 overlap:  0
# Host:  38 , index:  10 overlap:  0
# Host:  38 , index:  12 overlap:  0
# Host:  38 , index:  15 overlap:  0
# Host:  38 , index:  16 overlap:  0
# Host:  38 , index:  21 overlap:  0
# Host:  38 , index:  24 overlap:  0
# Host:  38 , index:  25 overlap:  0
# Host:  38 , index:  28 overlap:  0
#          Ttest_indResult(statistic=-65.60674209555678, pvalue=1.5521340641900583e-141)
# Host:  38 , index:  31 overlap:  0
# Host:  38 , index:  32 overlap:  0
# Host:  38 , index:  33 overlap:  0
# Host:  38 , index:  34 overlap:  0
# Host:  38 , index:  35 overlap:  0
# Host:  38 , index:  37 overlap:  0
# Host:  38 , index:  38 overlap:  137
# Host:  38 , index:  39 overlap:  0
#          Ttest_indResult(statistic=-0.4037827796223655, pvalue=0.6880378597046493)
#          38  match with  39
# Host:  38 , index:  40 overlap:  10
#          Ttest_indResult(statistic=1.6154696431948248, pvalue=0.12317046644400133)
#          38  match with  40
# Host:  38 , index:  41 overlap:  7
#          Ttest_indResult(statistic=-0.0003101490722643077, pvalue=0.9997536063873428)
#          38  match with  41
# Host:  38 , index:  42 overlap:  0
# Host:  38 , index:  43 overlap:  0
# Host:  38 , index:  44 overlap:  0
# Host:  38 , index:  45 overlap:  0
# Host:  38 , index:  46 overlap:  0
# Host:  42 , index:  0 overlap:  0
# Host:  42 , index:  1 overlap:  0
# Host:  42 , index:  8 overlap:  0
# Host:  42 , index:  10 overlap:  0
# Host:  42 , index:  12 overlap:  0
# Host:  42 , index:  15 overlap:  0
# Host:  42 , index:  16 overlap:  0
# Host:  42 , index:  21 overlap:  0
#          Ttest_indResult(statistic=30.172782702561623, pvalue=6.280402882968469e-28)
# Host:  42 , index:  24 overlap:  0
# Host:  42 , index:  25 overlap:  0
# Host:  42 , index:  28 overlap:  0
# Host:  42 , index:  31 overlap:  0
# Host:  42 , index:  32 overlap:  0
# Host:  42 , index:  33 overlap:  0
# Host:  42 , index:  34 overlap:  0
# Host:  42 , index:  35 overlap:  0
# Host:  42 , index:  37 overlap:  0
# Host:  42 , index:  38 overlap:  0
# Host:  42 , index:  42 overlap:  31
# Host:  42 , index:  43 overlap:  4
#          Ttest_indResult(statistic=-1.4298956716612745, pvalue=0.15893534413888263)
#          42  match with  43
# Host:  42 , index:  44 overlap:  0
#          Ttest_indResult(statistic=-0.7491706591170534, pvalue=0.457159734301505)
#          42  match with  44
# Host:  42 , index:  45 overlap:  2
#          Ttest_indResult(statistic=0.607551022770707, pvalue=0.5506449300325977)
#          42  match with  45
# Host:  42 , index:  46 overlap:  0
# Host:  46 , index:  0 overlap:  0
# Host:  46 , index:  1 overlap:  0
# Host:  46 , index:  8 overlap:  0
# Host:  46 , index:  10 overlap:  0
# Host:  46 , index:  12 overlap:  0
# Host:  46 , index:  15 overlap:  0
#          Ttest_indResult(statistic=2.4658993077651554, pvalue=0.015229756595875513)
# Host:  46 , index:  16 overlap:  0
# Host:  46 , index:  21 overlap:  0
# Host:  46 , index:  24 overlap:  0
# Host:  46 , index:  25 overlap:  0
# Host:  46 , index:  28 overlap:  0
# Host:  46 , index:  31 overlap:  0
# Host:  46 , index:  32 overlap:  0
# Host:  46 , index:  33 overlap:  0
# Host:  46 , index:  34 overlap:  0
# Host:  46 , index:  35 overlap:  0
# Host:  46 , index:  37 overlap:  0
# Host:  46 , index:  38 overlap:  0
# Host:  46 , index:  42 overlap:  0
# Host:  46 , index:  46 overlap:  108
# Host:  0 , index:  0 overlap:  367
# Host:  0 , index:  1 overlap:  122
#          Ttest_indResult(statistic=31.920019383456477, pvalue=2.526001869425467e-60)
# Host:  0 , index:  2 overlap:  0
# Host:  0 , index:  3 overlap:  0
# Host:  0 , index:  4 overlap:  0
# Host:  0 , index:  5 overlap:  0
#          Ttest_indResult(statistic=-7.26484338482655, pvalue=1.1563208301998693e-12)
# Host:  0 , index:  6 overlap:  0
# Host:  0 , index:  7 overlap:  0
# Host:  0 , index:  8 overlap:  0
# Host:  0 , index:  9 overlap:  0
# Host:  0 , index:  10 overlap:  0
# Host:  0 , index:  11 overlap:  0
# Host:  0 , index:  12 overlap:  0
# Host:  0 , index:  13 overlap:  0
# Host:  0 , index:  14 overlap:  0
# Host:  0 , index:  15 overlap:  0
# Host:  0 , index:  16 overlap:  0
# Host:  0 , index:  17 overlap:  0
# Host:  0 , index:  18 overlap:  0
# Host:  0 , index:  19 overlap:  0
# Host:  1 , index:  0 overlap:  2
#          Ttest_indResult(statistic=-31.920019383456477, pvalue=2.526001869425467e-60)
# Host:  1 , index:  1 overlap:  124
# Host:  1 , index:  2 overlap:  0
# Host:  1 , index:  3 overlap:  0
# Host:  1 , index:  4 overlap:  0
# Host:  1 , index:  5 overlap:  0
# Host:  1 , index:  6 overlap:  0
# Host:  1 , index:  7 overlap:  0
# Host:  1 , index:  8 overlap:  0
# Host:  1 , index:  9 overlap:  0
# Host:  1 , index:  10 overlap:  0
# Host:  1 , index:  11 overlap:  0
# Host:  1 , index:  12 overlap:  0
# Host:  1 , index:  13 overlap:  0
# Host:  1 , index:  14 overlap:  0
# Host:  1 , index:  15 overlap:  0
# Host:  1 , index:  16 overlap:  0
# Host:  1 , index:  17 overlap:  0
# Host:  1 , index:  18 overlap:  0
# Host:  1 , index:  19 overlap:  0
# Host:  2 , index:  0 overlap:  0
# Host:  2 , index:  1 overlap:  0
# Host:  2 , index:  2 overlap:  269
# Host:  2 , index:  3 overlap:  0
# Host:  2 , index:  4 overlap:  0
# Host:  2 , index:  5 overlap:  0
# Host:  2 , index:  6 overlap:  0
# Host:  2 , index:  7 overlap:  0
# Host:  2 , index:  8 overlap:  0
# Host:  2 , index:  9 overlap:  0
# Host:  2 , index:  10 overlap:  0
# Host:  2 , index:  11 overlap:  0
# Host:  2 , index:  12 overlap:  0
# Host:  2 , index:  13 overlap:  0
# Host:  2 , index:  14 overlap:  0
# Host:  2 , index:  15 overlap:  0
# Host:  2 , index:  16 overlap:  0
# Host:  2 , index:  17 overlap:  0
# Host:  2 , index:  18 overlap:  0
# Host:  2 , index:  19 overlap:  0
# Host:  3 , index:  0 overlap:  0
# Host:  3 , index:  1 overlap:  0
# Host:  3 , index:  2 overlap:  0
# Host:  3 , index:  3 overlap:  171
# Host:  3 , index:  4 overlap:  1
#          Ttest_indResult(statistic=2.6435630704319277, pvalue=0.01335080548354596)
# Host:  3 , index:  5 overlap:  0
# Host:  3 , index:  6 overlap:  0
# Host:  3 , index:  7 overlap:  0
# Host:  3 , index:  8 overlap:  0
# Host:  3 , index:  9 overlap:  0
# Host:  3 , index:  10 overlap:  0
#          Ttest_indResult(statistic=-66.97097963477935, pvalue=6.301325780060792e-137)
# Host:  3 , index:  11 overlap:  0
# Host:  3 , index:  12 overlap:  0
# Host:  3 , index:  13 overlap:  0
# Host:  3 , index:  14 overlap:  0
# Host:  3 , index:  15 overlap:  0
# Host:  3 , index:  16 overlap:  0
# Host:  3 , index:  17 overlap:  0
# Host:  3 , index:  18 overlap:  0
# Host:  3 , index:  19 overlap:  0
# Host:  4 , index:  0 overlap:  0
# Host:  4 , index:  1 overlap:  0
# Host:  4 , index:  2 overlap:  0
# Host:  4 , index:  3 overlap:  121
#          Ttest_indResult(statistic=-2.6435630704319277, pvalue=0.01335080548354596)
# Host:  4 , index:  4 overlap:  26
# Host:  4 , index:  5 overlap:  0
# Host:  4 , index:  6 overlap:  0
# Host:  4 , index:  7 overlap:  0
# Host:  4 , index:  8 overlap:  0
# Host:  4 , index:  9 overlap:  0
# Host:  4 , index:  10 overlap:  0
#          Ttest_indResult(statistic=-49.88204931203469, pvalue=1.9572221455206107e-45)
# Host:  4 , index:  11 overlap:  0
# Host:  4 , index:  12 overlap:  0
# Host:  4 , index:  13 overlap:  0
# Host:  4 , index:  14 overlap:  0
# Host:  4 , index:  15 overlap:  0
# Host:  4 , index:  16 overlap:  0
# Host:  4 , index:  17 overlap:  0
#          Ttest_indResult(statistic=14.722198232608411, pvalue=9.104430366354628e-18)
# Host:  4 , index:  18 overlap:  0
# Host:  4 , index:  19 overlap:  0
# Host:  5 , index:  0 overlap:  0
#          Ttest_indResult(statistic=7.26484338482655, pvalue=1.1563208301998693e-12)
# Host:  5 , index:  1 overlap:  0
# Host:  5 , index:  2 overlap:  0
# Host:  5 , index:  3 overlap:  0
# Host:  5 , index:  4 overlap:  0
# Host:  5 , index:  5 overlap:  503
# Host:  5 , index:  6 overlap:  187
#          Ttest_indResult(statistic=4.35975215786648, pvalue=2.000633527078794e-05)
# Host:  5 , index:  7 overlap:  0
# Host:  5 , index:  8 overlap:  0
# Host:  5 , index:  9 overlap:  0
#          Ttest_indResult(statistic=11.66082973562109, pvalue=1.9847794679473512e-23)
# Host:  5 , index:  10 overlap:  0
# Host:  5 , index:  11 overlap:  0
# Host:  5 , index:  12 overlap:  0
# Host:  5 , index:  13 overlap:  0
# Host:  5 , index:  14 overlap:  0
# Host:  5 , index:  15 overlap:  0
# Host:  5 , index:  16 overlap:  0
# Host:  5 , index:  17 overlap:  0
# Host:  5 , index:  18 overlap:  0
# Host:  5 , index:  19 overlap:  108
#          Ttest_indResult(statistic=-2.4658993077651554, pvalue=0.015229756595875513)
# Host:  6 , index:  0 overlap:  0
# Host:  6 , index:  1 overlap:  0
# Host:  6 , index:  2 overlap:  0
# Host:  6 , index:  3 overlap:  0
# Host:  6 , index:  4 overlap:  0
# Host:  6 , index:  5 overlap:  1
#          Ttest_indResult(statistic=-4.35975215786648, pvalue=2.000633527078794e-05)
# Host:  6 , index:  6 overlap:  187
# Host:  6 , index:  7 overlap:  0
# Host:  6 , index:  8 overlap:  0
# Host:  6 , index:  9 overlap:  0
# Host:  6 , index:  10 overlap:  0
# Host:  6 , index:  11 overlap:  0
# Host:  6 , index:  12 overlap:  0
# Host:  6 , index:  13 overlap:  0
# Host:  6 , index:  14 overlap:  0
# Host:  6 , index:  15 overlap:  0
# Host:  6 , index:  16 overlap:  0
# Host:  6 , index:  17 overlap:  0
# Host:  6 , index:  18 overlap:  0
# Host:  6 , index:  19 overlap:  0
# Host:  7 , index:  0 overlap:  0
# Host:  7 , index:  1 overlap:  0
# Host:  7 , index:  2 overlap:  0
# Host:  7 , index:  3 overlap:  0
# Host:  7 , index:  4 overlap:  0
# Host:  7 , index:  5 overlap:  0
# Host:  7 , index:  6 overlap:  0
# Host:  7 , index:  7 overlap:  287
# Host:  7 , index:  8 overlap:  0
# Host:  7 , index:  9 overlap:  0
# Host:  7 , index:  10 overlap:  0
# Host:  7 , index:  11 overlap:  0
# Host:  7 , index:  12 overlap:  0
# Host:  7 , index:  13 overlap:  0
# Host:  7 , index:  14 overlap:  0
# Host:  7 , index:  15 overlap:  0
# Host:  7 , index:  16 overlap:  0
# Host:  7 , index:  17 overlap:  0
# Host:  7 , index:  18 overlap:  0
#          Ttest_indResult(statistic=-47.24199459487464, pvalue=7.004889859649021e-150)
# Host:  7 , index:  19 overlap:  0
# Host:  8 , index:  0 overlap:  0
# Host:  8 , index:  1 overlap:  0
# Host:  8 , index:  2 overlap:  0
# Host:  8 , index:  3 overlap:  0
# Host:  8 , index:  4 overlap:  0
# Host:  8 , index:  5 overlap:  0
# Host:  8 , index:  6 overlap:  0
# Host:  8 , index:  7 overlap:  0
# Host:  8 , index:  8 overlap:  132
# Host:  8 , index:  9 overlap:  0
#          Ttest_indResult(statistic=-7.729476334753055, pvalue=1.486906927892171e-12)
# Host:  8 , index:  10 overlap:  0
# Host:  8 , index:  11 overlap:  0
# Host:  8 , index:  12 overlap:  0
# Host:  8 , index:  13 overlap:  0
# Host:  8 , index:  14 overlap:  0
# Host:  8 , index:  15 overlap:  0
# Host:  8 , index:  16 overlap:  0
# Host:  8 , index:  17 overlap:  0
# Host:  8 , index:  18 overlap:  0
# Host:  8 , index:  19 overlap:  0
# Host:  9 , index:  0 overlap:  0
# Host:  9 , index:  1 overlap:  0
# Host:  9 , index:  2 overlap:  0
# Host:  9 , index:  3 overlap:  0
# Host:  9 , index:  4 overlap:  0
# Host:  9 , index:  5 overlap:  0
#          Ttest_indResult(statistic=-11.66082973562109, pvalue=1.9847794679473512e-23)
# Host:  9 , index:  6 overlap:  0
# Host:  9 , index:  7 overlap:  0
# Host:  9 , index:  8 overlap:  0
#          Ttest_indResult(statistic=7.729476334753055, pvalue=1.486906927892171e-12)
# Host:  9 , index:  9 overlap:  181
# Host:  9 , index:  10 overlap:  0
# Host:  9 , index:  11 overlap:  0
# Host:  9 , index:  12 overlap:  0
# Host:  9 , index:  13 overlap:  0
# Host:  9 , index:  14 overlap:  0
# Host:  9 , index:  15 overlap:  0
# Host:  9 , index:  16 overlap:  0
# Host:  9 , index:  17 overlap:  0
# Host:  9 , index:  18 overlap:  0
# Host:  9 , index:  19 overlap:  0
# Host:  10 , index:  0 overlap:  0
# Host:  10 , index:  1 overlap:  0
# Host:  10 , index:  2 overlap:  0
# Host:  10 , index:  3 overlap:  0
#          Ttest_indResult(statistic=66.97097963477935, pvalue=6.301325780060792e-137)
# Host:  10 , index:  4 overlap:  0
#          Ttest_indResult(statistic=49.88204931203469, pvalue=1.9572221455206107e-45)
# Host:  10 , index:  5 overlap:  0
# Host:  10 , index:  6 overlap:  0
# Host:  10 , index:  7 overlap:  0
# Host:  10 , index:  8 overlap:  0
# Host:  10 , index:  9 overlap:  0
# Host:  10 , index:  10 overlap:  177
# Host:  10 , index:  11 overlap:  0
# Host:  10 , index:  12 overlap:  0
# Host:  10 , index:  13 overlap:  0
# Host:  10 , index:  14 overlap:  0
# Host:  10 , index:  15 overlap:  0
# Host:  10 , index:  16 overlap:  0
#          Ttest_indResult(statistic=47.03793126608213, pvalue=7.638248681678056e-71)
# Host:  10 , index:  17 overlap:  0
#          Ttest_indResult(statistic=78.36005399342801, pvalue=2.7239965230157568e-188)
# Host:  10 , index:  18 overlap:  0
#          Ttest_indResult(statistic=47.2889086091738, pvalue=5.156008827949071e-122)
# Host:  10 , index:  19 overlap:  0
# Host:  11 , index:  0 overlap:  0
# Host:  11 , index:  1 overlap:  0
# Host:  11 , index:  2 overlap:  0
# Host:  11 , index:  3 overlap:  0
# Host:  11 , index:  4 overlap:  0
# Host:  11 , index:  5 overlap:  0
# Host:  11 , index:  6 overlap:  0
# Host:  11 , index:  7 overlap:  0
# Host:  11 , index:  8 overlap:  0
# Host:  11 , index:  9 overlap:  0
# Host:  11 , index:  10 overlap:  0
# Host:  11 , index:  11 overlap:  107
# Host:  11 , index:  12 overlap:  0
# Host:  11 , index:  13 overlap:  0
# Host:  11 , index:  14 overlap:  0
# Host:  11 , index:  15 overlap:  0
# Host:  11 , index:  16 overlap:  0
# Host:  11 , index:  17 overlap:  0
# Host:  11 , index:  18 overlap:  0
# Host:  11 , index:  19 overlap:  0
# Host:  12 , index:  0 overlap:  0
# Host:  12 , index:  1 overlap:  0
# Host:  12 , index:  2 overlap:  0
# Host:  12 , index:  3 overlap:  0
# Host:  12 , index:  4 overlap:  0
# Host:  12 , index:  5 overlap:  0
# Host:  12 , index:  6 overlap:  0
# Host:  12 , index:  7 overlap:  0
# Host:  12 , index:  8 overlap:  0
# Host:  12 , index:  9 overlap:  0
# Host:  12 , index:  10 overlap:  0
# Host:  12 , index:  11 overlap:  0
# Host:  12 , index:  12 overlap:  55
# Host:  12 , index:  13 overlap:  0
#          Ttest_indResult(statistic=3.0294840218698935, pvalue=0.007752967730058061)
# Host:  12 , index:  14 overlap:  0
# Host:  12 , index:  15 overlap:  0
# Host:  12 , index:  16 overlap:  0
# Host:  12 , index:  17 overlap:  0
# Host:  12 , index:  18 overlap:  0
# Host:  12 , index:  19 overlap:  0
# Host:  13 , index:  0 overlap:  0
# Host:  13 , index:  1 overlap:  0
# Host:  13 , index:  2 overlap:  0
# Host:  13 , index:  3 overlap:  0
# Host:  13 , index:  4 overlap:  0
# Host:  13 , index:  5 overlap:  0
# Host:  13 , index:  6 overlap:  0
# Host:  13 , index:  7 overlap:  0
# Host:  13 , index:  8 overlap:  0
# Host:  13 , index:  9 overlap:  0
# Host:  13 , index:  10 overlap:  0
# Host:  13 , index:  11 overlap:  0
# Host:  13 , index:  12 overlap:  2
#          Ttest_indResult(statistic=-3.0294840218698935, pvalue=0.007752967730058061)
# Host:  13 , index:  13 overlap:  24
# Host:  13 , index:  14 overlap:  0
# Host:  13 , index:  15 overlap:  0
# Host:  13 , index:  16 overlap:  0
# Host:  13 , index:  17 overlap:  0
# Host:  13 , index:  18 overlap:  0
# Host:  13 , index:  19 overlap:  0
# Host:  14 , index:  0 overlap:  0
# Host:  14 , index:  1 overlap:  0
# Host:  14 , index:  2 overlap:  0
# Host:  14 , index:  3 overlap:  0
# Host:  14 , index:  4 overlap:  0
# Host:  14 , index:  5 overlap:  0
# Host:  14 , index:  6 overlap:  0
# Host:  14 , index:  7 overlap:  0
# Host:  14 , index:  8 overlap:  0
# Host:  14 , index:  9 overlap:  0
# Host:  14 , index:  10 overlap:  0
# Host:  14 , index:  11 overlap:  0
# Host:  14 , index:  12 overlap:  0
# Host:  14 , index:  13 overlap:  0
# Host:  14 , index:  14 overlap:  116
# Host:  14 , index:  15 overlap:  2
#          Ttest_indResult(statistic=3.6847935870857063, pvalue=0.003455023928413923)
# Host:  14 , index:  16 overlap:  0
# Host:  14 , index:  17 overlap:  0
# Host:  14 , index:  18 overlap:  0
# Host:  14 , index:  19 overlap:  0
# Host:  15 , index:  0 overlap:  0
# Host:  15 , index:  1 overlap:  0
# Host:  15 , index:  2 overlap:  0
# Host:  15 , index:  3 overlap:  0
# Host:  15 , index:  4 overlap:  0
# Host:  15 , index:  5 overlap:  0
# Host:  15 , index:  6 overlap:  0
# Host:  15 , index:  7 overlap:  0
# Host:  15 , index:  8 overlap:  0
# Host:  15 , index:  9 overlap:  0
# Host:  15 , index:  10 overlap:  0
# Host:  15 , index:  11 overlap:  0
# Host:  15 , index:  12 overlap:  0
# Host:  15 , index:  13 overlap:  0
# Host:  15 , index:  14 overlap:  1
#          Ttest_indResult(statistic=-3.6847935870857063, pvalue=0.003455023928413923)
# Host:  15 , index:  15 overlap:  17
# Host:  15 , index:  16 overlap:  0
# Host:  15 , index:  17 overlap:  0
# Host:  15 , index:  18 overlap:  0
# Host:  15 , index:  19 overlap:  0
# Host:  16 , index:  0 overlap:  0
# Host:  16 , index:  1 overlap:  0
# Host:  16 , index:  2 overlap:  0
# Host:  16 , index:  3 overlap:  0
# Host:  16 , index:  4 overlap:  0
# Host:  16 , index:  5 overlap:  0
# Host:  16 , index:  6 overlap:  0
# Host:  16 , index:  7 overlap:  0
# Host:  16 , index:  8 overlap:  0
# Host:  16 , index:  9 overlap:  0
# Host:  16 , index:  10 overlap:  0
#          Ttest_indResult(statistic=-47.03793126608213, pvalue=7.638248681678056e-71)
# Host:  16 , index:  11 overlap:  0
# Host:  16 , index:  12 overlap:  0
# Host:  16 , index:  13 overlap:  0
# Host:  16 , index:  14 overlap:  0
# Host:  16 , index:  15 overlap:  0
# Host:  16 , index:  16 overlap:  86
# Host:  16 , index:  17 overlap:  0
# Host:  16 , index:  18 overlap:  0
# Host:  16 , index:  19 overlap:  0
# Host:  17 , index:  0 overlap:  0
# Host:  17 , index:  1 overlap:  0
# Host:  17 , index:  2 overlap:  0
# Host:  17 , index:  3 overlap:  0
# Host:  17 , index:  4 overlap:  0
#          Ttest_indResult(statistic=-14.722198232608411, pvalue=9.104430366354628e-18)
# Host:  17 , index:  5 overlap:  0
# Host:  17 , index:  6 overlap:  0
# Host:  17 , index:  7 overlap:  0
# Host:  17 , index:  8 overlap:  0
# Host:  17 , index:  9 overlap:  0
# Host:  17 , index:  10 overlap:  0
#          Ttest_indResult(statistic=-78.36005399342801, pvalue=2.7239965230157568e-188)
# Host:  17 , index:  11 overlap:  0
# Host:  17 , index:  12 overlap:  0
# Host:  17 , index:  13 overlap:  0
# Host:  17 , index:  14 overlap:  0
# Host:  17 , index:  15 overlap:  0
# Host:  17 , index:  16 overlap:  0
# Host:  17 , index:  17 overlap:  247
# Host:  17 , index:  18 overlap:  0
# Host:  17 , index:  19 overlap:  0
# Host:  18 , index:  0 overlap:  0
# Host:  18 , index:  1 overlap:  0
# Host:  18 , index:  2 overlap:  0
# Host:  18 , index:  3 overlap:  0
# Host:  18 , index:  4 overlap:  0
# Host:  18 , index:  5 overlap:  0
# Host:  18 , index:  6 overlap:  0
# Host:  18 , index:  7 overlap:  0
#          Ttest_indResult(statistic=47.24199459487464, pvalue=7.004889859649021e-150)
# Host:  18 , index:  8 overlap:  0
# Host:  18 , index:  9 overlap:  0
# Host:  18 , index:  10 overlap:  0
#          Ttest_indResult(statistic=-47.2889086091738, pvalue=5.156008827949071e-122)
# Host:  18 , index:  11 overlap:  0
# Host:  18 , index:  12 overlap:  0
# Host:  18 , index:  13 overlap:  0
# Host:  18 , index:  14 overlap:  0
# Host:  18 , index:  15 overlap:  0
# Host:  18 , index:  16 overlap:  0
# Host:  18 , index:  17 overlap:  0
# Host:  18 , index:  18 overlap:  203
# Host:  18 , index:  19 overlap:  0
# Host:  19 , index:  0 overlap:  0
# Host:  19 , index:  1 overlap:  0
# Host:  19 , index:  2 overlap:  0
# Host:  19 , index:  3 overlap:  0
# Host:  19 , index:  4 overlap:  0
# Host:  19 , index:  5 overlap:  0
#          Ttest_indResult(statistic=2.4658993077651554, pvalue=0.015229756595875513)
# Host:  19 , index:  6 overlap:  0
# Host:  19 , index:  7 overlap:  0
# Host:  19 , index:  8 overlap:  0
# Host:  19 , index:  9 overlap:  0
# Host:  19 , index:  10 overlap:  0
# Host:  19 , index:  11 overlap:  0
# Host:  19 , index:  12 overlap:  0
# Host:  19 , index:  13 overlap:  0
# Host:  19 , index:  14 overlap:  0
# Host:  19 , index:  15 overlap:  0
# Host:  19 , index:  16 overlap:  0
# Host:  19 , index:  17 overlap:  0
# Host:  19 , index:  18 overlap:  0
# Host:  19 , index:  19 overlap:  108

# %% [markdown]
# ## Plots

# %%
# Plot benchmark
BMplot = mpl.pyplot.figure()
### Sky map cluster plot
ax1 = BMplot.add_subplot(1, 2, 1)
plt.grid()
mpl.pyplot.scatter(BenchMarktHRx, BenchMark[:,1])
ax1 = BMplot.add_subplot(1, 2, 2)
plt.grid()
mpl.pyplot.scatter(BenchMarktHRx, BenchMarktHRy)

# %%
# Plot subClusters
subClusterPlots=[]
for i, subCluster in enumerate(subClusters):
    subClusterPlots.append(mpl.pyplot.figure())
    ### Sky map cluster plot
    ax1 = subClusterPlots[-1].add_subplot(1, 3, 1)
    plt.grid()
    mpl.pyplot.scatter(subCluster[:,1], subCluster[:,2], c= subCluster[:,5], cmap= 'bwr', marker ='x')
    ### HR diagram cluster plot
    ax2 = subClusterPlots[-1].add_subplot(1, 3, 2)
    plt.grid()
    mpl.pyplot.scatter(subCluster[:,3],subCluster[:,4], marker = 'x', color='blue')
 
    ax3 = subClusterPlots[-1].add_subplot(1, 3, 3)
    
    mpl.pyplot.scatter(subClusterMS[i][:,0],subClusterMS[i][:,1], marker = '+', color='green')
    # ax3.fill(X_plot, subCluster[2], fc="#AAAAFF")
    # ax3.set_xlim(min(farPoints_floats[:,5]),2)
    ax3.set_ylim(-10,-2)
    plt.grid()
plt.show()

# %%
# Plot clusters
clusterPlots=[]
for i, cluster in enumerate(clusters):
    clusterPlots.append(mpl.pyplot.figure())
    ### Sky map cluster plot
    ax1 = clusterPlots[-1].add_subplot(1, 3, 1)
    plt.grid()
    mpl.pyplot.scatter(cluster[:,1], cluster[:,2], c= cluster[:,5], cmap= 'bwr', marker ='x')
    ### HR diagram cluster plot
    ax2 = clusterPlots[-1].add_subplot(1, 3, 2)
    plt.grid()
    mpl.pyplot.scatter(cluster[:,3],cluster[:,4], marker = 'x', color='blue')
    ax3 = clusterPlots[-1].add_subplot(1, 3, 3)
    mpl.pyplot.scatter(clusterMS[i][:,0],clusterMS[i][:,1], marker = '+', color='green')
    ax3.set_ylim(-10,-2)
    plt.grid()
plt.show()

# %%
totalPointsSC = 0
totalPointsC = 0
totalPointsP = 0
unassigned = unassigned

totalPointsP = 0
for protoCluster in protoClusters:
    totalPointsP = totalPointsP + len(protoCluster)
    
totalPointsSC = 0    
for subCluster in subClusters:
    totalPointsSC = totalPointsSC + len(subCluster)
    
totalPointsC = 0
for cluster in clusters:
    totalPointsC = totalPointsC + len(cluster)
