# %% [markdown]
# # imports

# %%
# import required libraries
import os
import numpy as np
import scipy as sp
import matplotlib as mpl
from astropy.table import Table
import glob
import warnings

# configure notebook for plotting
# %pylab inline --no-import-all 
mpl.style.use('seaborn-colorblind') # colourblind-friendly colour scheme
colours = mpl.rcParams['axes.prop_cycle'].by_key()['color'] # allows access to colours
# subsequent lines default plot settings
matplotlib.rcParams['image.origin'] = 'lower'
matplotlib.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
matplotlib.rcParams['font.size']=16              #10 
matplotlib.rcParams['savefig.dpi']= 300             #72 

warnings.filterwarnings('ignore')

# import data from Data directory
allPointsFiles = glob.glob('../Data/*/*/points.txt')
allFuzzyFiles = glob.glob('../Data/*/*/fuzzy.txt')
closePoints = []
totalPoints = 0

# take all close points as reference and plot

fig = plt.figure()
plt.ylabel('Absolute magnitude')
plt.xlabel('Log Flux 2 - Log Flux 0')
plt.title('Benchmark Points')

for j, pointsFile in enumerate(allPointsFiles):
    try:
        this = Table.read(pointsFile,format='ascii')
        totalPoints= totalPoints+len(this)
        thispar = this['par']
        thism0, thism1, thism2 = (np.log10(this['flux1']), 
                                  np.log10(this['flux2']), 
                                  np.log10(this['flux3']))
        thiscolour = thism2-thism0
        dist = 1/thispar
        abs_mag = thism1 + 2*np.log10(dist)
        
        points = Table([this['name'], thispar, thiscolour, abs_mag]).as_array().tolist()
        
        
        for point in points:
            if point[1] > 0.01:
                closePoints.append(point)
                plt.scatter(point[2],point[3],color=colours[1])
    except:
        pass
    
print(totalPoints)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ../Data\Back\A01\points.txt
# ../Data\Back\A02\points.txt
# ../Data\Back\A03\points.txt
# ../Data\Back\A04\points.txt
# ../Data\Back\A05\points.txt
# ../Data\Back\A06\points.txt
# ../Data\Back\B01\points.txt
# ../Data\Back\B02\points.txt
# ../Data\Back\B03\points.txt
# ../Data\Back\B04\points.txt
# ../Data\Back\B05\points.txt
# ../Data\Back\B06\points.txt
# ../Data\Back\C01\points.txt
# ../Data\Back\C02\points.txt
# ../Data\Back\C03\points.txt
# ../Data\Back\C04\points.txt
# ../Data\Back\C05\points.txt
# ../Data\Back\C06\points.txt
# ../Data\Back\D01\points.txt
# ../Data\Back\D02\points.txt
# ../Data\Back\D03\points.txt
# ../Data\Back\D04\points.txt
# ../Data\Back\D05\points.txt
# ../Data\Back\D06\points.txt
# ../Data\Back\E01\points.txt
# ../Data\Back\E02\points.txt
# ../Data\Back\E03\points.txt
# ../Data\Back\E04\points.txt
# ../Data\Back\E05\points.txt
# ../Data\Back\E06\points.txt
# ../Data\Back\F01\points.txt
# ../Data\Back\F02\points.txt
# ../Data\Back\F03\points.txt
# ../Data\Back\F04\points.txt
# ../Data\Back\F05\points.txt
# ../Data\Back\F06\points.txt
# ../Data\Down\A01\points.txt
# ../Data\Down\A02\points.txt
# ../Data\Down\A03\points.txt
# ../Data\Down\A04\points.txt
# ../Data\Down\A05\points.txt
# ../Data\Down\A06\points.txt
# ../Data\Down\B01\points.txt
# ../Data\Down\B02\points.txt
# ../Data\Down\B03\points.txt
# ../Data\Down\B04\points.txt
# ../Data\Down\B05\points.txt
# ../Data\Down\B06\points.txt
# ../Data\Down\C01\points.txt
# ../Data\Down\C02\points.txt
# ../Data\Down\C03\points.txt
# ../Data\Down\C04\points.txt
# ../Data\Down\C05\points.txt
# ../Data\Down\C06\points.txt
# ../Data\Down\D01\points.txt
# ../Data\Down\D02\points.txt
# ../Data\Down\D03\points.txt
# ../Data\Down\D04\points.txt
# ../Data\Down\D05\points.txt
# ../Data\Down\D06\points.txt
# ../Data\Down\E01\points.txt
# ../Data\Down\E02\points.txt
# ../Data\Down\E03\points.txt
# ../Data\Down\E04\points.txt
# ../Data\Down\E05\points.txt
# ../Data\Down\E06\points.txt
# ../Data\Down\F01\points.txt
# ../Data\Down\F02\points.txt
# ../Data\Down\F03\points.txt
# ../Data\Down\F04\points.txt
# ../Data\Down\F05\points.txt
# ../Data\Down\F06\points.txt
# ../Data\Front\A01\points.txt
# ../Data\Front\A02\points.txt
# ../Data\Front\A03\points.txt
# ../Data\Front\A04\points.txt
# ../Data\Front\A05\points.txt
# ../Data\Front\A06\points.txt
# ../Data\Front\B01\points.txt
# ../Data\Front\B02\points.txt
# ../Data\Front\B03\points.txt
# ../Data\Front\B04\points.txt
# ../Data\Front\B05\points.txt
# ../Data\Front\B06\points.txt
# ../Data\Front\C01\points.txt
# ../Data\Front\C02\points.txt
# ../Data\Front\C03\points.txt
# ../Data\Front\C04\points.txt
# ../Data\Front\C05\points.txt
# ../Data\Front\C06\points.txt
# ../Data\Front\D01\points.txt
# ../Data\Front\D02\points.txt
# ../Data\Front\D03\points.txt
# ../Data\Front\D04\points.txt
# ../Data\Front\D05\points.txt
# ../Data\Front\D06\points.txt
# ../Data\Front\E01\points.txt
# ../Data\Front\E02\points.txt
# ../Data\Front\E03\points.txt
# ../Data\Front\E04\points.txt
# ../Data\Front\E05\points.txt
# ../Data\Front\E06\points.txt
# ../Data\Front\F01\points.txt
# ../Data\Front\F02\points.txt
# ../Data\Front\F03\points.txt
# ../Data\Front\F04\points.txt
# ../Data\Front\F05\points.txt
# ../Data\Front\F06\points.txt
# ../Data\Left\A01\points.txt
# ../Data\Left\A02\points.txt
# ../Data\Left\A03\points.txt
# ../Data\Left\A04\points.txt
# ../Data\Left\A05\points.txt
# ../Data\Left\A06\points.txt
# ../Data\Left\B01\points.txt
# ../Data\Left\B02\points.txt
# ../Data\Left\B03\points.txt
# ../Data\Left\B04\points.txt
# ../Data\Left\B05\points.txt
# ../Data\Left\B06\points.txt
# ../Data\Left\C01\points.txt
# ../Data\Left\C02\points.txt
# ../Data\Left\C03\points.txt
# ../Data\Left\C04\points.txt
# ../Data\Left\C05\points.txt
# ../Data\Left\C06\points.txt
# ../Data\Left\D01\points.txt
# ../Data\Left\D02\points.txt
# ../Data\Left\D03\points.txt
# ../Data\Left\D04\points.txt
# ../Data\Left\D05\points.txt
# ../Data\Left\D06\points.txt
# ../Data\Left\E01\points.txt
# ../Data\Left\E02\points.txt
# ../Data\Left\E03\points.txt
# ../Data\Left\E04\points.txt
# ../Data\Left\E05\points.txt
# ../Data\Left\E06\points.txt
# ../Data\Left\F01\points.txt
# ../Data\Left\F02\points.txt
# ../Data\Left\F03\points.txt
# ../Data\Left\F04\points.txt
# ../Data\Left\F05\points.txt
# ../Data\Left\F06\points.txt
# ../Data\Right\A01\points.txt
# ../Data\Right\A02\points.txt
# ../Data\Right\A03\points.txt
# ../Data\Right\A04\points.txt
# ../Data\Right\A05\points.txt
# ../Data\Right\A06\points.txt
# ../Data\Right\B01\points.txt
# ../Data\Right\B02\points.txt
# ../Data\Right\B03\points.txt
# ../Data\Right\B04\points.txt
# ../Data\Right\B05\points.txt
# ../Data\Right\B06\points.txt
# ../Data\Right\C01\points.txt
# ../Data\Right\C02\points.txt
# ../Data\Right\C03\points.txt
# ../Data\Right\C04\points.txt
# ../Data\Right\C05\points.txt
# ../Data\Right\C06\points.txt
# ../Data\Right\D01\points.txt
# ../Data\Right\D02\points.txt
# ../Data\Right\D03\points.txt
# ../Data\Right\D04\points.txt
# ../Data\Right\D05\points.txt
# ../Data\Right\D06\points.txt
# ../Data\Right\E01\points.txt
# ../Data\Right\E02\points.txt
# ../Data\Right\E03\points.txt
# ../Data\Right\E04\points.txt
# ../Data\Right\E05\points.txt
# ../Data\Right\E06\points.txt
# ../Data\Right\F01\points.txt
# ../Data\Right\F02\points.txt
# ../Data\Right\F03\points.txt
# ../Data\Right\F04\points.txt
# ../Data\Right\F05\points.txt
# ../Data\Right\F06\points.txt
# ../Data\Up\A01\points.txt
# ../Data\Up\A02\points.txt
# ../Data\Up\A03\points.txt
# ../Data\Up\A04\points.txt
# ../Data\Up\A05\points.txt
# ../Data\Up\A06\points.txt
# ../Data\Up\B01\points.txt
# ../Data\Up\B02\points.txt
# ../Data\Up\B03\points.txt
# ../Data\Up\B04\points.txt
# ../Data\Up\B05\points.txt
# ../Data\Up\B06\points.txt
# ../Data\Up\C01\points.txt
# ../Data\Up\C02\points.txt
# ../Data\Up\C03\points.txt
# ../Data\Up\C04\points.txt
# ../Data\Up\C05\points.txt
# ../Data\Up\C06\points.txt
# ../Data\Up\D01\points.txt
# ../Data\Up\D02\points.txt
# ../Data\Up\D03\points.txt
# ../Data\Up\D04\points.txt
# ../Data\Up\D05\points.txt
# ../Data\Up\D06\points.txt
# ../Data\Up\E01\points.txt
# ../Data\Up\E02\points.txt
# ../Data\Up\E03\points.txt
# ../Data\Up\E04\points.txt
# ../Data\Up\E05\points.txt
# ../Data\Up\E06\points.txt
# ../Data\Up\F01\points.txt
# ../Data\Up\F02\points.txt
# ../Data\Up\F03\points.txt
# ../Data\Up\F04\points.txt
# ../Data\Up\F05\points.txt
# ../Data\Up\F06\points.txt
# 3665

# %%
# Out:
# Text(0.5, 0, 'Log Flux 2 - Log Flux 0')
